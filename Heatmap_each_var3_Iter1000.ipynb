# %% [markdown]
# <a href="https://colab.research.google.com/github/Pengchengzhi/Face-Alignment-DRF/blob/main/Heatmap_each_var3_Iter1000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This program generates one heatmap for each landmark, while `Heatmap_all.ipynb` generates one heatmap for all landmarks.

# %% [markdown]
# * 不要用 Gaussian 做 Label，匹配 Loss Function 的形状，保证理论上误差为0.

# %% [markdown]
# # 1. Initialize

# %%
# function ConnectButton(){
#   console.log("Connect pushed"); 
#   document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click() 
# }
# setInterval(ConnectButton,60000);


# clearInterval(37042)

# %%
from google.colab import drive
drive.mount("/content/drive")

import os
path="/content/drive/My Drive/Face Alignment DRF"
os.chdir(path)
os.listdir(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['Procruses Analysis.ipynb',
#  'PCA.ipynb',
#  '__pycache__',
#  'utils',
#  'datasets',
#  'Gaussian.ipynb',
#  'Heatmap_all.ipynb',
#  'trained_models',
#  'DataPreprocessing.ipynb',
#  'checkpoints',
#  'Update_leaf.ipynb',
#  'Heatmap_each.ipynb']

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import os
import cv2
import json
import pandas as pd
from PIL import Image
import torchvision.models as models
import pdb
from torch.nn import Upsample
from torch.autograd import Variable
import torch.optim as optim
import time

import warnings
warnings.filterwarnings('ignore')

# %%
from utils.hourglass import *
from utils.dataloader import *

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
dim_tree = 5 # how deep the regression tree is 
num_tree = 3 # number of regression trees
variance_gaussian = 3

num_fc = int(num_tree*(2**(dim_tree-1)-1))
num_leaf_nodes = int(num_tree*2**(dim_tree-1))

# %% [markdown]
# # 2. Data Loader

# %%
helen_trainset = Helen_set(dataset_type="train",var=variance_gaussian)
# Out:
# Loading [1/2000] pictures......
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-79e9d4e17ca4> in <module>()
# ----> 1 helen_trainset = Helen_set(dataset_type="train")
#
# /content/drive/My Drive/Face Alignment DRF/utils/dataloader.py in __init__(self, dataset_type, var)
#      46       key = self.keys[i]
#      47       path = os.path.join(img_path, key + '.jpg')
# ---> 48       pic = cv2.imread(path)
#      49       pic = cv2.cvtColor(pic, cv2.COLOR_BGR2RGB)
#      50       self.imgs[i,:,:,:] = torch.from_numpy(pic).permute(2,0,1)
#
# KeyboardInterrupt:

# %%
helen_testset = Helen_set(dataset_type="test",var=variance_gaussian)

# %%
train_dataloder = DataLoader(helen_trainset, batch_size=30)
test_dataloder = DataLoader(helen_testset, batch_size=30)

# %% [markdown]
# # 3. Pre Train

# %%
helen_sampleset = Helen_set(dataset_type="sample")
sample_dataloder = DataLoader(helen_sampleset, batch_size=20)
# Out:
# Loading [1/200] pictures......
# Loading [100/200] pictures......
# Loading [200/200] pictures......

# %%
critical = torch.nn.MSELoss()

nIters = 200
HGNet = HGNet().to(device)
optimizer = optim.SGD(HGNet.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-4)

# %%
loss_hist = torch.zeros(nIters)
loss_epoch = torch.zeros(10)

for iter in range(nIters):
  for i, (x,_,y) in enumerate(sample_dataloder):
    x = Variable(x,requires_grad=True).float().to(device)
    y = Variable(y).float().to(device)
    y_pred = HGNet.forward(x)
    loss = critical(y_pred, y)
    loss_epoch[i] = loss.item()

    if i == 9:
      loss_avg = torch.sum(loss_epoch)/10
      loss_hist[iter] = loss_avg
      if (iter+1)%10 == 0 or iter == 0:
        print('Iter [%d/%d] loss %.4f' %(iter+1, nIters, loss_avg))
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

plt.plot(torch.arange(nIters),loss_hist.detach().numpy())
plt.title("Training Loss")
# Out:
# Iter [1/200] loss 0.4851
# Iter [10/200] loss 0.3919
# Iter [20/200] loss 0.3299
# Iter [30/200] loss 0.2775
# Iter [40/200] loss 0.2264
# Iter [50/200] loss 0.1907
# Iter [60/200] loss 0.1593
# Iter [70/200] loss 0.1372
# Iter [80/200] loss 0.1207
# Iter [90/200] loss 0.1067
# Iter [100/200] loss 0.0961
# Iter [110/200] loss 0.0875
# Iter [120/200] loss 0.0809
# Iter [130/200] loss 0.0753
# Iter [140/200] loss 0.0708
# Iter [150/200] loss 0.0667
# Iter [160/200] loss 0.0625
# Iter [170/200] loss 0.0536
# Iter [180/200] loss 0.0481
# Iter [190/200] loss 0.0452
# Iter [200/200] loss 0.0411
# Text(0.5, 1.0, 'Training Loss')

# %%
# torch.save(HGNet.state_dict(), "/content/drive/My Drive/Face Alignment DRF/trained_models/Original_HGNet.pt")

# %% [markdown]
# # 4. Tune Training

# %% [markdown]
# ## 4.1 Functions

# %% [markdown]
# ![PHI.png](data:image/png;base64,...)

# %%
def leaf_direction(N):
  point = torch.zeros(2**N,N).to(device)

  def get01(number, len):
    result = torch.zeros(len).to(device)
    ind = len
    while ind >0:
      if 2**(ind-1)<=number:
        result[len-ind] = 1
        number -= 2**(ind-1)
      ind -= 1
    return result
  
  for i in range(2**N):
    point[i,:] = get01(i,N)

  return point.int()

# %%
def split_tree(up,here,which=0,mode='Second'):
  if mode=='initial':
    if which == 0:
      return here
    else: return (1-here)
  else:
    if which == 0:
      return up*here
    else: return up*(1-here)

# %%
def split_base(N):
  # returns index that split based on which cnn_fc col
  res = torch.zeros(2**N*N).to(device)
  lenth = 2**(N-1)
  num = 1
  left = 0
  repeat = 1
  max_repeat = 1
  while lenth>0 and repeat<2**N:
    res[left:left+lenth*2] = num
    left += lenth*2
    num += 1
    repeat -= 1
    if repeat == 0:
      lenth = int(lenth/2)
      repeat = max_repeat*2
      max_repeat = repeat
  return ((res.reshape(N,2**N)-1).T).int()

# %%
def phi(cnn_fc):
  N = cnn_fc.shape[0]
  out = torch.zeros(N,num_leaf_nodes).to(device)
  sigm = torch.sigmoid(cnn_fc)

  direction = leaf_direction(dim_tree-1)
  tree_ind = split_base(dim_tree-1)
  X, Y = tree_ind.shape

  for ind_tree in range(num_tree):
    for x in range(X):
      for y in range(Y):
        here = sigm[:,ind_tree*(X-1)+tree_ind[x,y]]
        if y == 0:
          up = split_tree(torch.rand(3).to(device),here,which=direction[x,y],mode='initial')
        else:
          up = split_tree(up,here,which=direction[x,y])
        #print('y',y,'up',up)

      out[:,ind_tree*X+x] = up
    
  return out

# %%
def find_coord(prob_map):
  # prob_map(200,68*256*256)

  N = prob_map.shape[0]
  P = 12
  coord = torch.zeros(N,P*2).to(device)
  heatmap = prob_map.reshape(N,P,256,256).float()
  for n in range(N):
    for p in range(P):
      c1, c2 = torch.where(heatmap[n,p,:,:]==torch.max(heatmap[n,p,:,:]))
      coord[n,2*p], coord[n,2*p+1] = c1[0], c2[0]

  return coord

# %%
def get_mask(cnn_heatmaps,threshold=0.3):
  mask = torch.zeros(cnn_heatmaps.shape).to(device)
  B, P = cnn_heatmaps.shape[0:2]
  for b in range(B):
    for p in range(P):
      hm = cnn_heatmaps[b,p,:,:]
      mask[b,p,:,:][hm>torch.max(hm)*threshold]=1
  return mask

# %%
def update_iter(q, p, l):
  # q: leaf node
  # p: cnn probability
  # l: label

  gamma = torch.unsqueeze(p,2)*torch.unsqueeze(q,0) # (Ntrain,Nleaf,Nlabel)
  gamma = gamma/(torch.sum(gamma,axis=1,keepdims=True)+1e-8)
  score = torch.zeros(gamma.shape).to(q.device)
  for ll in range(q.shape[0]):
    score[:,ll,:] = l*gamma[:,ll,:]
  score = torch.sum(score,axis=0)+1e-8 # (3,2)

  return score/torch.sum(score,axis=1,keepdims=True)

# %%
def loss_ce(B, q, p, l):
  pred = torch.matmul(p,q.reshape(num_leaf_nodes,-1)).reshape(B*12,-1)
  pred = pred/torch.sum(pred,axis=1,keepdims=True)
  l = l.reshape(B*12,-1)
  l = l/torch.sum(l,axis=1,keepdims=True)

  return -criterion_KL(pred,l)

def loss_l1(q, p, l):
  return torch.sum(torch.abs(torch.matmul(p,q)-l))/l.shape[0]

# %%
# def mask_and_norm(target, mask):
#   # target (B,12,256,256)
#   # mask (B,12,256,256)
#   B,P = target.shape[0:2]

#   res = (target*mask).reshape(B,P,-1)
#   res = res/torch.sum(res,axis=2,keepdims=True)
#   return res.reshape(B,-1)

# %% [markdown]
# ## 4.2 Sample Set

# %%
helen_sampleset = Helen_set(dataset_type="sample",var=variance_gaussian)
sample_dataloder = DataLoader(helen_sampleset, batch_size=20)
helen_sampletest = Helen_set(dataset_type="sample_test",var=variance_gaussian)
sample_test_dataloder = DataLoader(helen_sampletest, batch_size=10)
# Out:
# Loading [1/200] pictures......
# Loading [100/200] pictures......
# Loading [200/200] pictures......
# Loading [1/30] pictures......

# %% [markdown]
# ## 4.3 Network

# %%
Tune_HGNet = HGNet(tune=True).to(device)
Tune_HGNet.load_state_dict(torch.load("/content/drive/My Drive/Face Alignment DRF/trained_models/Original_HGNet.pt"))
# Out:
# <All keys matched successfully>

# %%
Tune_HGNet._HGNet__lin = nn.Sequential(nn.Conv2d(128,64,1),
                    nn.BatchNorm2d(64),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(4,4),  #(64,64,64)
                    nn.Conv2d(64,16,1),
                    nn.BatchNorm2d(16),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2),  #(16,32,32)
                    nn.Conv2d(16,4,1),
                    nn.BatchNorm2d(4),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2)).to(device)  #(4,16,16)

Tune_HGNet._HGNet__tune = nn.Sequential(nn.Linear(4*16*16,num_fc)).to(device)

# %% [markdown]
# ## 4.4 Training

# %%
#######################
# Initialization
Total_train = 8

# CNN initilization
nIters = 1000

criterion_MSE = torch.nn.MSELoss()
criterion_KL = torch.nn.KLDivLoss()
optimizer = optim.SGD(Tune_HGNet.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-4)

# Regression Tree parameters
rf_Iters = 60

# %% [markdown]
# ### Training using L2 Loss

# %%
# Using L2 Loss

for round in range(Total_train):
  print("###########################################################")
  if torch.cuda.is_available():
    print("Round %d, Using GPU" %(round+1))
  else:
    print("Round ", round+1)
  
  #####################################
  ### Train Hourglass
  ### eyes: [36:48]
  #####################################
  if round == 0:
    leaf_q = torch.ones(num_leaf_nodes,12*256*256).to(device)/(256*256)
    cnn_Iters = 30
  else:
    cnn_Iters = nIters

  for iter in range(cnn_Iters):
    loss_epoch = 0
    for i, (x,_,y) in enumerate(sample_dataloder):
      x = x.float().to(device)
      x.requires_grad = True
      y = y.float().to(device)
      B = x.shape[0]

      outputs = Tune_HGNet.forward(x)
      cnn_prob = phi(outputs)
      cnn_heatmaps = torch.matmul(cnn_prob,leaf_q).reshape(B,12,256,256)
      # get mask for computing cnn loss
      cnn_mask = get_mask(cnn_heatmaps,threshold=0.5)
      loss = criterion_MSE(cnn_heatmaps*cnn_mask, y[:,36:48,:,:]*cnn_mask)

      loss_epoch += loss.item()
      if (iter+1)%20 == 0 or iter == 0:
        if i == 9:
          print('     CNN training, Iter [%d/%d], loss_L2: %.8f' %(iter+1, cnn_Iters, loss_epoch*224*224*1e-1))

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()


  #####################################
  ### Train Regression Trees using pinv
  #####################################
  with torch.no_grad():
    leaf_q_new = torch.zeros(num_leaf_nodes,12*256*256).to(device)
    loss0 = 0

    for i, (x,coord,y) in enumerate(sample_dataloder):
      x = x.float().to(device)
      y = y.float().to(device)
      coord = coord.float().to(device)
      B = x.shape[0]
      y_expand = y[:,36:48,:,:].reshape(B,-1) #(200,12*256*256)

      outputs = Tune_HGNet.forward(x)
      cnn_prob = phi(outputs)

      pred_coord0 = find_coord(torch.matmul(cnn_prob,leaf_q))
      loss0 += torch.sum(torch.abs(pred_coord0-coord[:,36:48,:].reshape(B,-1)))

      leaf_q_new += torch.matmul(torch.linalg.pinv(cnn_prob), y_expand) #(8,12*256*256)

    leaf_q = leaf_q_new/10  # average among each bach
    leaf_q = torch.abs(leaf_q.reshape(num_leaf_nodes,12,-1)) #(B,12,256*256)
    leaf_q = leaf_q/torch.sum(leaf_q, axis=2, keepdims=True)
    for nleaf in range(num_leaf_nodes):
      for npoints in range(12):
        leaf_q[nleaf,npoints,:][leaf_q[nleaf,npoints,:] <= torch.max(leaf_q[nleaf,npoints,:])*0.2] = 0
    leaf_q = leaf_q/torch.sum(leaf_q, axis=2, keepdims=True)
    leaf_q = leaf_q.reshape(num_leaf_nodes,-1)

    print("     RF training, coordinate loss: %.4f" %(loss0/10))

# %% [markdown]
# ### Training using Log likelihood

# %%
# update using log likelihood

time_initial = time.time()
for round in range(Total_train):
  time_start = time.time()
  print("############################################################################")
  if torch.cuda.is_available():
    print("Round %d, Using GPU" %(round+1))
  else:
    print("Round ", round+1)

  
  ######################################################
  ### Train Hourglass
  ### eyes: [36:48]
  ######################################################
  if round == 0:
    leaf_q = torch.ones(num_leaf_nodes,12,256*256).to(device)/(256*256)
    cnn_Iters = 30
  else:
    cnn_Iters = nIters

  for iter in range(cnn_Iters):
    loss_epoch = 0
    for i, (x,_,y) in enumerate(sample_dataloder):
      x = x.float().to(device)
      x.requires_grad = True
      y = y.float().to(device)
      B = x.shape[0]

      outputs = Tune_HGNet.forward(x)
      cnn_prob = phi(outputs)

      cnn_heatmaps = torch.matmul(cnn_prob,leaf_q.reshape(num_leaf_nodes,-1)).reshape(B*12,-1)
      cnn_heatmaps = cnn_heatmaps/torch.sum(cnn_heatmaps,axis=1,keepdims=True)
      label_heatmaps = y[:,36:48,:,:].reshape(B*12,-1)
      label_heatmaps = label_heatmaps/torch.sum(label_heatmaps,axis=1,keepdims=True)
      loss = -criterion_KL(cnn_heatmaps,label_heatmaps)

      loss_epoch += loss.item()
      if (iter+1)%50 == 0 or iter == 0:
        if i == 9:
          print('     CNN training, Iter [%d/%d], loss_KL: %.6f' %(iter+1, cnn_Iters, loss_epoch*224*224*1e-1))

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

  time_cnn = time.time()
  print("     -----> CNN training time: ## %.2f mins ## " %((time_cnn-time_start)/60))
  ######################################################
  ### Train Regression Trees using variational bounding
  ######################################################
  with torch.no_grad():
    loss0 = 0

    leaf_q = leaf_q.reshape(num_leaf_nodes,12,256*256)
    for i, (x,coord,y) in enumerate(sample_dataloder):
      x = x.float().to(device)
      y = y.float().to(device)
      coord = coord.float().to(device)
      B = x.shape[0]
      y_expand = y[:,36:48,:,:].reshape(B,12,-1) #(200,12*256*256)

      outputs = Tune_HGNet.forward(x)
      cnn_prob = phi(outputs)

  
      for rf_iter in range(rf_Iters):
        for points_id in range(12):
          leaf_q[:,points_id,:] = update_iter(leaf_q[:,points_id,:], cnn_prob, y_expand[:,points_id,:])
        if ((i+1)%4 == 0 or i == 0) and ((rf_iter+1)%15 == 0 or rf_iter == 0):
          rf_loss_CE = loss_ce(B, leaf_q, cnn_prob, y_expand)
          print("     RF training, Batch %d, rf_iter [%d/%d], loss_KL: %.4f" %(i+1, rf_iter+1, rf_Iters, rf_loss_CE*224*224))


      pred_coord0 = find_coord(torch.matmul(cnn_prob,leaf_q.reshape(num_leaf_nodes,-1)))
      loss0 += torch.sum(torch.abs(pred_coord0-coord[:,36:48,:].reshape(B,-1)))


    # Sharpen Leaf_q
    # leaf_q = leaf_q.reshape(num_leaf_nodes,12,256*256)
    # for nleaf in range(num_leaf_nodes):
    #   for npoints in range(12):
    #     leaf_q[nleaf,npoints,:][leaf_q[nleaf,npoints,:] <= torch.max(leaf_q[nleaf,npoints,:])*0.2] = 0
    # leaf_q = leaf_q/torch.sum(leaf_q, axis=2, keepdims=True)
    # leaf_q = leaf_q.reshape(num_leaf_nodes,-1)


    print("     RF training, coordinate loss: %.4f" %(loss0/10))


  torch.save(Tune_HGNet.state_dict(), os.path.join("checkpoints/CNN1000/var_"+str(variance_gaussian),"Tune_HGNet_Loss_KL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round)+'.pt'))
  torch.save(leaf_q, os.path.join("checkpoints/CNN1000/var_"+str(variance_gaussian),"leaf_q_Loss_KL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round)+'.pt'))

  time_rf = time.time()
  print("     -----> RF training time: ## %.2f mins ## " %((time_rf-time_cnn)/60))
  print("     -----> Training time for this round: ## %.2f mins ## " %((time_rf-time_start)/60))

# Finish Training
torch.save(Tune_HGNet.state_dict(), os.path.join("checkpoints/CNN1000/var_"+str(variance_gaussian),"Tune_HGNet_Loss_KL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_final.pt"))
torch.save(leaf_q, os.path.join("checkpoints/CNN1000/var_"+str(variance_gaussian),"leaf_q_Loss_KL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_final.pt"))

time_end = time.time()
print("-----> Total training time: ## %.2f hrs ## " %((time_end-time_initial)/3600))
# Out:
# ############################################################################
# Round 1, Using GPU
#      CNN training, Iter [1/30], loss_KL: 3.854769
#      -----> CNN training time: ## 1.99 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [15/60], loss_KL: 3.8559
#      RF training, Batch 1, rf_iter [30/60], loss_KL: 3.8560
#      RF training, Batch 1, rf_iter [45/60], loss_KL: 3.8560
#      RF training, Batch 1, rf_iter [60/60], loss_KL: 3.8560
#      RF training, Batch 4, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 4, rf_iter [15/60], loss_KL: 3.8557
#      RF training, Batch 4, rf_iter [30/60], loss_KL: 3.8558
#      RF training, Batch 4, rf_iter [45/60], loss_KL: 3.8558
#      RF training, Batch 4, rf_iter [60/60], loss_KL: 3.8559
#      RF training, Batch 8, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 8, rf_iter [15/60], loss_KL: 3.8558
#      RF training, Batch 8, rf_iter [30/60], loss_KL: 3.8558
#      RF training, Batch 8, rf_iter [45/60], loss_KL: 3.8559
#      RF training, Batch 8, rf_iter [60/60], loss_KL: 3.8559
#      RF training, coordinate loss: 6056.3477
#      -----> RF training time: ## 10.70 mins ##
#      -----> Training time for this round: ## 12.69 mins ##
# ############################################################################
# Round 2, Using GPU
#      CNN training, Iter [1/1000], loss_KL: 3.855064
#      CNN training, Iter [50/1000], loss_KL: 3.855063
#      CNN training, Iter [100/1000], loss_KL: 3.855063
#      CNN training, Iter [150/1000], loss_KL: 3.855062
#      CNN training, Iter [200/1000], loss_KL: 3.855062
#      CNN training, Iter [250/1000], loss_KL: 3.855062
#      CNN training, Iter [300/1000], loss_KL: 3.855061
#      CNN training, Iter [350/1000], loss_KL: 3.855061
#      CNN training, Iter [400/1000], loss_KL: 3.855061
#      CNN training, Iter [450/1000], loss_KL: 3.855060
#      CNN training, Iter [500/1000], loss_KL: 3.855060
#      CNN training, Iter [550/1000], loss_KL: 3.855059
#      CNN training, Iter [600/1000], loss_KL: 3.855059
#      CNN training, Iter [650/1000], loss_KL: 3.855059
#      CNN training, Iter [700/1000], loss_KL: 3.855058
#      CNN training, Iter [750/1000], loss_KL: 3.855058
#      CNN training, Iter [800/1000], loss_KL: 3.855058
#      CNN training, Iter [850/1000], loss_KL: 3.855057
#      CNN training, Iter [900/1000], loss_KL: 3.855057
#      CNN training, Iter [950/1000], loss_KL: 3.855057
#      CNN training, Iter [1000/1000], loss_KL: 3.855057
#      -----> CNN training time: ## 65.84 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 1, rf_iter [15/60], loss_KL: 3.8558
#      RF training, Batch 1, rf_iter [30/60], loss_KL: 3.8558
#      RF training, Batch 1, rf_iter [45/60], loss_KL: 3.8559
#      RF training, Batch 1, rf_iter [60/60], loss_KL: 3.8559
#      RF training, Batch 4, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 4, rf_iter [15/60], loss_KL: 3.8557
#      RF training, Batch 4, rf_iter [30/60], loss_KL: 3.8557
#      RF training, Batch 4, rf_iter [45/60], loss_KL: 3.8558
#      RF training, Batch 4, rf_iter [60/60], loss_KL: 3.8558
#      RF training, Batch 8, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 8, rf_iter [15/60], loss_KL: 3.8557
#      RF training, Batch 8, rf_iter [30/60], loss_KL: 3.8558
#      RF training, Batch 8, rf_iter [45/60], loss_KL: 3.8558
#      RF training, Batch 8, rf_iter [60/60], loss_KL: 3.8558
#      RF training, coordinate loss: 6366.1460
#      -----> RF training time: ## 10.66 mins ##
#      -----> Training time for this round: ## 76.50 mins ##
# ############################################################################
# Round 3, Using GPU
#      CNN training, Iter [1/1000], loss_KL: 3.855057
#      CNN training, Iter [50/1000], loss_KL: 3.855057
#      CNN training, Iter [100/1000], loss_KL: 3.855056
#      CNN training, Iter [150/1000], loss_KL: 3.855056
#      CNN training, Iter [200/1000], loss_KL: 3.855056
#      CNN training, Iter [250/1000], loss_KL: 3.855056
#      CNN training, Iter [300/1000], loss_KL: 3.855055
#      CNN training, Iter [350/1000], loss_KL: 3.855055
#      CNN training, Iter [400/1000], loss_KL: 3.855055
#      CNN training, Iter [450/1000], loss_KL: 3.855054
#      CNN training, Iter [500/1000], loss_KL: 3.855054
#      CNN training, Iter [550/1000], loss_KL: 3.855054
#      CNN training, Iter [600/1000], loss_KL: 3.855053
#      CNN training, Iter [650/1000], loss_KL: 3.855053
#      CNN training, Iter [700/1000], loss_KL: 3.855053
#      CNN training, Iter [750/1000], loss_KL: 3.855053
#      CNN training, Iter [800/1000], loss_KL: 3.855052
#      CNN training, Iter [850/1000], loss_KL: 3.855052
#      CNN training, Iter [900/1000], loss_KL: 3.855052
#      CNN training, Iter [950/1000], loss_KL: 3.855051
#      CNN training, Iter [1000/1000], loss_KL: 3.855051
#      -----> CNN training time: ## 65.96 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 1, rf_iter [15/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [30/60], loss_KL: 3.8558
#      RF training, Batch 1, rf_iter [45/60], loss_KL: 3.8558
#      RF training, Batch 1, rf_iter [60/60], loss_KL: 3.8558
#      RF training, Batch 4, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 4, rf_iter [15/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [30/60], loss_KL: 3.8557
#      RF training, Batch 4, rf_iter [45/60], loss_KL: 3.8557
#      RF training, Batch 4, rf_iter [60/60], loss_KL: 3.8557
#      RF training, Batch 8, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 8, rf_iter [15/60], loss_KL: 3.8557
#      RF training, Batch 8, rf_iter [30/60], loss_KL: 3.8557
#      RF training, Batch 8, rf_iter [45/60], loss_KL: 3.8557
#      RF training, Batch 8, rf_iter [60/60], loss_KL: 3.8558
#      RF training, coordinate loss: 6576.6221
#      -----> RF training time: ## 10.67 mins ##
#      -----> Training time for this round: ## 76.63 mins ##
# ############################################################################
# Round 4, Using GPU
#      CNN training, Iter [1/1000], loss_KL: 3.855052
#      CNN training, Iter [50/1000], loss_KL: 3.855052
#      CNN training, Iter [100/1000], loss_KL: 3.855051
#      CNN training, Iter [150/1000], loss_KL: 3.855051
#      CNN training, Iter [200/1000], loss_KL: 3.855051
#      CNN training, Iter [250/1000], loss_KL: 3.855051
#      CNN training, Iter [300/1000], loss_KL: 3.855050
#      CNN training, Iter [350/1000], loss_KL: 3.855050
#      CNN training, Iter [400/1000], loss_KL: 3.855050
#      CNN training, Iter [450/1000], loss_KL: 3.855049
#      CNN training, Iter [500/1000], loss_KL: 3.855049
#      CNN training, Iter [550/1000], loss_KL: 3.855049
#      CNN training, Iter [600/1000], loss_KL: 3.855049
#      CNN training, Iter [650/1000], loss_KL: 3.855049
#      CNN training, Iter [700/1000], loss_KL: 3.855048
#      CNN training, Iter [750/1000], loss_KL: 3.855048
#      CNN training, Iter [800/1000], loss_KL: 3.855048
#      CNN training, Iter [850/1000], loss_KL: 3.855048
#      CNN training, Iter [900/1000], loss_KL: 3.855047
#      CNN training, Iter [950/1000], loss_KL: 3.855047
#      CNN training, Iter [1000/1000], loss_KL: 3.855047
#      -----> CNN training time: ## 66.11 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 1, rf_iter [15/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [30/60], loss_KL: 3.8558
#      RF training, Batch 1, rf_iter [45/60], loss_KL: 3.8558
#      RF training, Batch 1, rf_iter [60/60], loss_KL: 3.8558
#      RF training, Batch 4, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 4, rf_iter [15/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [30/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [45/60], loss_KL: 3.8557
#      RF training, Batch 4, rf_iter [60/60], loss_KL: 3.8557
#      RF training, Batch 8, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 8, rf_iter [15/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [30/60], loss_KL: 3.8557
#      RF training, Batch 8, rf_iter [45/60], loss_KL: 3.8557
#      RF training, Batch 8, rf_iter [60/60], loss_KL: 3.8557
#      RF training, coordinate loss: 6682.9229
#      -----> RF training time: ## 10.67 mins ##
#      -----> Training time for this round: ## 76.78 mins ##
# ############################################################################
# Round 5, Using GPU
#      CNN training, Iter [1/1000], loss_KL: 3.855048
#      CNN training, Iter [50/1000], loss_KL: 3.855047
#      CNN training, Iter [100/1000], loss_KL: 3.855047
#      CNN training, Iter [150/1000], loss_KL: 3.855047
#      CNN training, Iter [200/1000], loss_KL: 3.855047
#      CNN training, Iter [250/1000], loss_KL: 3.855046
#      CNN training, Iter [300/1000], loss_KL: 3.855046
#      CNN training, Iter [350/1000], loss_KL: 3.855046
#      CNN training, Iter [400/1000], loss_KL: 3.855046
#      CNN training, Iter [450/1000], loss_KL: 3.855046
#      CNN training, Iter [500/1000], loss_KL: 3.855046
#      CNN training, Iter [550/1000], loss_KL: 3.855045
#      CNN training, Iter [600/1000], loss_KL: 3.855045
#      CNN training, Iter [650/1000], loss_KL: 3.855045
#      CNN training, Iter [700/1000], loss_KL: 3.855045
#      CNN training, Iter [750/1000], loss_KL: 3.855045
#      CNN training, Iter [800/1000], loss_KL: 3.855044
#      CNN training, Iter [850/1000], loss_KL: 3.855044
#      CNN training, Iter [900/1000], loss_KL: 3.855044
#      CNN training, Iter [950/1000], loss_KL: 3.855044
#      CNN training, Iter [1000/1000], loss_KL: 3.855044
#      -----> CNN training time: ## 66.16 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 1, rf_iter [15/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [30/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [45/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [60/60], loss_KL: 3.8558
#      RF training, Batch 4, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 4, rf_iter [15/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [30/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [45/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [60/60], loss_KL: 3.8557
#      RF training, Batch 8, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 8, rf_iter [15/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [30/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [45/60], loss_KL: 3.8557
#      RF training, Batch 8, rf_iter [60/60], loss_KL: 3.8557
#      RF training, coordinate loss: 6860.0112
#      -----> RF training time: ## 10.69 mins ##
#      -----> Training time for this round: ## 76.85 mins ##
# ############################################################################
# Round 6, Using GPU
#      CNN training, Iter [1/1000], loss_KL: 3.855043
#      CNN training, Iter [50/1000], loss_KL: 3.855043
#      CNN training, Iter [100/1000], loss_KL: 3.855043
#      CNN training, Iter [150/1000], loss_KL: 3.855043
#      CNN training, Iter [200/1000], loss_KL: 3.855043
#      CNN training, Iter [250/1000], loss_KL: 3.855043
#      CNN training, Iter [300/1000], loss_KL: 3.855043
#      CNN training, Iter [350/1000], loss_KL: 3.855042
#      CNN training, Iter [400/1000], loss_KL: 3.855042
#      CNN training, Iter [450/1000], loss_KL: 3.855042
#      CNN training, Iter [500/1000], loss_KL: 3.855042
#      CNN training, Iter [550/1000], loss_KL: 3.855042
#      CNN training, Iter [600/1000], loss_KL: 3.855041
#      CNN training, Iter [650/1000], loss_KL: 3.855041
#      CNN training, Iter [700/1000], loss_KL: 3.855041
#      CNN training, Iter [750/1000], loss_KL: 3.855041
#      CNN training, Iter [800/1000], loss_KL: 3.855041
#      CNN training, Iter [850/1000], loss_KL: 3.855041
#      CNN training, Iter [900/1000], loss_KL: 3.855040
#      CNN training, Iter [950/1000], loss_KL: 3.855040
#      CNN training, Iter [1000/1000], loss_KL: 3.855040
#      -----> CNN training time: ## 66.03 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 1, rf_iter [15/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [30/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [45/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [60/60], loss_KL: 3.8557
#      RF training, Batch 4, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 4, rf_iter [15/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [30/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [45/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [60/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 8, rf_iter [15/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [30/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [45/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [60/60], loss_KL: 3.8557
#      RF training, coordinate loss: 6954.9971
#      -----> RF training time: ## 10.66 mins ##
#      -----> Training time for this round: ## 76.69 mins ##
# ############################################################################
# Round 7, Using GPU
#      CNN training, Iter [1/1000], loss_KL: 3.855040
#      CNN training, Iter [50/1000], loss_KL: 3.855040
#      CNN training, Iter [100/1000], loss_KL: 3.855040
#      CNN training, Iter [150/1000], loss_KL: 3.855040
#      CNN training, Iter [200/1000], loss_KL: 3.855040
#      CNN training, Iter [250/1000], loss_KL: 3.855039
#      CNN training, Iter [300/1000], loss_KL: 3.855039
#      CNN training, Iter [350/1000], loss_KL: 3.855039
#      CNN training, Iter [400/1000], loss_KL: 3.855039
#      CNN training, Iter [450/1000], loss_KL: 3.855039
#      CNN training, Iter [500/1000], loss_KL: 3.855039
#      CNN training, Iter [550/1000], loss_KL: 3.855039
#      CNN training, Iter [600/1000], loss_KL: 3.855039
#      CNN training, Iter [650/1000], loss_KL: 3.855038
#      CNN training, Iter [700/1000], loss_KL: 3.855038
#      CNN training, Iter [750/1000], loss_KL: 3.855038
#      CNN training, Iter [800/1000], loss_KL: 3.855038
#      CNN training, Iter [850/1000], loss_KL: 3.855038
#      CNN training, Iter [900/1000], loss_KL: 3.855038
#      CNN training, Iter [950/1000], loss_KL: 3.855038
#      CNN training, Iter [1000/1000], loss_KL: 3.855037
#      -----> CNN training time: ## 65.80 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 1, rf_iter [15/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [30/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [45/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [60/60], loss_KL: 3.8557
#      RF training, Batch 4, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 4, rf_iter [15/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [30/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [45/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [60/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 8, rf_iter [15/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [30/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [45/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [60/60], loss_KL: 3.8556
#      RF training, coordinate loss: 7009.3838
#      -----> RF training time: ## 10.65 mins ##
#      -----> Training time for this round: ## 76.45 mins ##
# ############################################################################
# Round 8, Using GPU
#      CNN training, Iter [1/1000], loss_KL: 3.855038
#      CNN training, Iter [50/1000], loss_KL: 3.855038
#      CNN training, Iter [100/1000], loss_KL: 3.855037
#      CNN training, Iter [150/1000], loss_KL: 3.855037
#      CNN training, Iter [200/1000], loss_KL: 3.855037
#      CNN training, Iter [250/1000], loss_KL: 3.855037
#      CNN training, Iter [300/1000], loss_KL: 3.855037
#      CNN training, Iter [350/1000], loss_KL: 3.855037
#      CNN training, Iter [400/1000], loss_KL: 3.855037
#      CNN training, Iter [450/1000], loss_KL: 3.855037
#      CNN training, Iter [500/1000], loss_KL: 3.855036
#      CNN training, Iter [550/1000], loss_KL: 3.855036
#      CNN training, Iter [600/1000], loss_KL: 3.855036
#      CNN training, Iter [650/1000], loss_KL: 3.855036
#      CNN training, Iter [700/1000], loss_KL: 3.855036
#      CNN training, Iter [750/1000], loss_KL: 3.855036
#      CNN training, Iter [800/1000], loss_KL: 3.855036
#      CNN training, Iter [850/1000], loss_KL: 3.855036
#      CNN training, Iter [900/1000], loss_KL: 3.855036
#      CNN training, Iter [950/1000], loss_KL: 3.855035
#      CNN training, Iter [1000/1000], loss_KL: 3.855035
#      -----> CNN training time: ## 65.76 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 1, rf_iter [15/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [30/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [45/60], loss_KL: 3.8557
#      RF training, Batch 1, rf_iter [60/60], loss_KL: 3.8557
#      RF training, Batch 4, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 4, rf_iter [15/60], loss_KL: 3.8555
#      RF training, Batch 4, rf_iter [30/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [45/60], loss_KL: 3.8556
#      RF training, Batch 4, rf_iter [60/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [1/60], loss_KL: 3.8555
#      RF training, Batch 8, rf_iter [15/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [30/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [45/60], loss_KL: 3.8556
#      RF training, Batch 8, rf_iter [60/60], loss_KL: 3.8556
#      RF training, coordinate loss: 7092.6167
#      -----> RF training time: ## 10.65 mins ##
#      -----> Training time for this round: ## 76.41 mins ##
# -----> Total training time: ## 9.15 hrs ##

# %% [markdown]
# ## 4.5 Test

# %% [markdown]
# ### Restore from saved weights

# %%
Tune_HGNet = HGNet(tune=True).to(device)
Tune_HGNet._HGNet__lin = nn.Sequential(nn.Conv2d(128,64,1),
                    nn.BatchNorm2d(64),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(4,4),  #(64,64,64)
                    nn.Conv2d(64,16,1),
                    nn.BatchNorm2d(16),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2),  #(16,32,32)
                    nn.Conv2d(16,4,1),
                    nn.BatchNorm2d(4),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2)).to(device)  #(4,16,16)

Tune_HGNet._HGNet__tune = nn.Sequential(nn.Linear(4*16*16,num_fc)).to(device)

Tune_HGNet.load_state_dict(torch.load(os.path.join("checkpoints/var_"+str(variance_gaussian),"Tune_HGNet_Loss_KL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_final.pt")))
leaf_q = torch.load(os.path.join("checkpoints/var_"+str(variance_gaussian),"leaf_q_Loss_KL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_final.pt"))

# %%
import torchsummary
def count_parameters(model):
  return sum(p.numel() for p in model.parameters() if p.requires_grad)
torchsummary.summary(Tune_HGNet, (3,256,256))
print('parameters_count:',count_parameters(Tune_HGNet))

# %% [markdown]
# ### Test

# %%
heatmap_loss, coord_loss = 0, 0
Tune_HGNet.eval()
criterion = torch.nn.MSELoss()

for i, (img,coord,hm) in enumerate(sample_test_dataloder):
  img = img.float().to(device)
  img.requires_grad = True
  coord = coord.float().to(device)
  hm = hm.float().to(device)
  B = img.shape[0]
  
  outputs = Tune_HGNet.forward(img)
  pred_heatmaps = torch.matmul(phi(outputs),leaf_q.reshape(num_leaf_nodes,-1)) #(15,12*256*256)
  pred_coords = find_coord(pred_heatmaps) #(15,12*2)

  heatmap_loss += criterion(pred_heatmaps, hm[:,36:48,:,:].reshape(B,-1))
  coord_loss += torch.sum(torch.abs(pred_coords-coord[:,36:48,:].reshape(B,-1)))

print("Heatmap loss %.8f, Coord loss %.4f" %(heatmap_loss/10, coord_loss/10))
# Out:
# Heatmap loss 0.00012895, Coord loss 1124.7848

# %%
phi(outputs)[0:5,:]
# Out:
# tensor([[0.0554, 0.0622, 0.0793, 0.0651, 0.0660, 0.0586, 0.0519, 0.0658, 0.0746,
#          0.0664, 0.0752, 0.0684, 0.0579, 0.0540, 0.0472, 0.0520, 0.0680, 0.0694,
#          0.0771, 0.0660, 0.0696, 0.0601, 0.0586, 0.0637, 0.0439, 0.0577, 0.0621,
#          0.0709, 0.0678, 0.0561, 0.0481, 0.0610, 0.0749, 0.0688, 0.0651, 0.0656,
#          0.0685, 0.0764, 0.0640, 0.0518, 0.0649, 0.0598, 0.0426, 0.0725, 0.0600,
#          0.0604, 0.0535, 0.0512],
#         [0.0520, 0.0649, 0.0710, 0.0698, 0.0580, 0.0622, 0.0692, 0.0760, 0.0641,
#          0.0499, 0.0636, 0.0767, 0.0577, 0.0604, 0.0538, 0.0508, 0.0662, 0.0606,
#          0.0549, 0.0597, 0.0618, 0.0666, 0.0697, 0.0640, 0.0586, 0.0595, 0.0647,
#          0.0711, 0.0576, 0.0594, 0.0605, 0.0650, 0.0685, 0.0643, 0.0641, 0.0608,
#          0.0595, 0.0666, 0.0585, 0.0642, 0.0636, 0.0618, 0.0579, 0.0696, 0.0604,
#          0.0588, 0.0569, 0.0643],
#         [0.0606, 0.0678, 0.0723, 0.0655, 0.0717, 0.0623, 0.0630, 0.0646, 0.0679,
#          0.0601, 0.0665, 0.0625, 0.0546, 0.0523, 0.0494, 0.0587, 0.0670, 0.0650,
#          0.0563, 0.0531, 0.0606, 0.0648, 0.0530, 0.0600, 0.0615, 0.0580, 0.0664,
#          0.0693, 0.0705, 0.0545, 0.0703, 0.0697, 0.0718, 0.0702, 0.0649, 0.0725,
#          0.0551, 0.0584, 0.0646, 0.0503, 0.0539, 0.0536, 0.0470, 0.0631, 0.0697,
#          0.0767, 0.0659, 0.0623],
#         [0.0597, 0.0598, 0.0822, 0.0672, 0.0713, 0.0629, 0.0642, 0.0700, 0.0657,
#          0.0521, 0.0689, 0.0635, 0.0590, 0.0503, 0.0505, 0.0525, 0.0631, 0.0634,
#          0.0673, 0.0643, 0.0606, 0.0577, 0.0624, 0.0602, 0.0585, 0.0544, 0.0751,
#          0.0654, 0.0667, 0.0540, 0.0598, 0.0670, 0.0640, 0.0677, 0.0729, 0.0661,
#          0.0623, 0.0714, 0.0670, 0.0581, 0.0535, 0.0568, 0.0470, 0.0687, 0.0637,
#          0.0666, 0.0545, 0.0596],
#         [0.0720, 0.0680, 0.0733, 0.0642, 0.0629, 0.0621, 0.0527, 0.0523, 0.0726,
#          0.0642, 0.0703, 0.0631, 0.0621, 0.0452, 0.0533, 0.0616, 0.0672, 0.0686,
#          0.0604, 0.0686, 0.0653, 0.0695, 0.0644, 0.0803, 0.0533, 0.0485, 0.0633,
#          0.0608, 0.0622, 0.0470, 0.0577, 0.0630, 0.0705, 0.0789, 0.0647, 0.0616,
#          0.0662, 0.0635, 0.0666, 0.0598, 0.0455, 0.0554, 0.0561, 0.0665, 0.0616,
#          0.0659, 0.0600, 0.0570]], device='cuda:0', grad_fn=<SliceBackward>)

# %%
for ith in range(8):
  x = pred_coords[ith,::2].detach().cpu()
  y = pred_coords[ith,1::2].detach().cpu()
  plt.scatter(x,256-y,label="Prediction %d" %ith)

  plt.legend(loc='lower left')
  plt.xlim(0,256)
  plt.ylim(0,256)

# %%
ith = 0

x = pred_coords[ith,::2].detach().cpu()
y = pred_coords[ith,1::2].detach().cpu()
plt.scatter(x,256-y,label="Prediction")

x2 = coord[ith,36:48,0].detach().cpu()
y2 = coord[ith,36:48,1].detach().cpu()
plt.scatter(x2,256-y2,label="GT")

plt.legend(loc='lower left')
plt.xlim(0,256)
plt.ylim(0,256)
# Out:
# (0.0, 256.0)

# %%
ith = 1

x = pred_coords[ith,::2].detach().cpu()
y = pred_coords[ith,1::2].detach().cpu()
plt.scatter(x,256-y,label="Prediction")

x2 = coord[ith,36:48,0].detach().cpu()
y2 = coord[ith,36:48,1].detach().cpu()
plt.scatter(x2,256-y2,label="GT")

plt.legend(loc='lower left')
plt.xlim(0,256)
plt.ylim(0,256)
# Out:
# (0.0, 256.0)

# %%
ith = 2

x = pred_coords[ith,::2].detach().cpu()
y = pred_coords[ith,1::2].detach().cpu()
plt.scatter(x,256-y,label="Prediction")

x2 = coord[ith,36:48,0].detach().cpu()
y2 = coord[ith,36:48,1].detach().cpu()
plt.scatter(x2,256-y2,label="GT")

plt.legend(loc='lower left')
plt.xlim(0,256)
plt.ylim(0,256)
# Out:
# (0.0, 256.0)

# %%
ith = 3

x = pred_coords[ith,::2].detach().cpu()
y = pred_coords[ith,1::2].detach().cpu()
plt.scatter(x,256-y,label="Prediction")

x2 = coord[ith,36:48,0].detach().cpu()
y2 = coord[ith,36:48,1].detach().cpu()
plt.scatter(x2,256-y2,label="GT")

plt.legend(loc='lower left')
plt.xlim(0,256)
plt.ylim(0,256)
# Out:
# (0.0, 256.0)

# %%
ith = 4

x = pred_coords[ith,::2].detach().cpu()
y = pred_coords[ith,1::2].detach().cpu()
plt.scatter(x,256-y,label="Prediction")

x2 = coord[ith,36:48,0].detach().cpu()
y2 = coord[ith,36:48,1].detach().cpu()
plt.scatter(x2,256-y2,label="GT")

plt.legend(loc='lower left')
plt.xlim(0,256)
plt.ylim(0,256)
# Out:
# (0.0, 256.0)

# %%
ith = 5

x = pred_coords[ith,::2].detach().cpu()
y = pred_coords[ith,1::2].detach().cpu()
plt.scatter(x,256-y,label="Prediction")

x2 = coord[ith,36:48,0].detach().cpu()
y2 = coord[ith,36:48,1].detach().cpu()
plt.scatter(x2,256-y2,label="GT")

plt.legend(loc='lower left')
plt.xlim(0,256)
plt.ylim(0,256)
# Out:
# (0.0, 256.0)

# %%
ith = 6

x = pred_coords[ith,::2].detach().cpu()
y = pred_coords[ith,1::2].detach().cpu()
plt.scatter(x,256-y,label="Prediction")

x2 = coord[ith,36:48,0].detach().cpu()
y2 = coord[ith,36:48,1].detach().cpu()
plt.scatter(x2,256-y2,label="GT")

plt.legend(loc='lower left')
plt.xlim(0,256)
plt.ylim(0,256)
# Out:
# (0.0, 256.0)

# %%
ith = 7

x = pred_coords[ith,::2].detach().cpu()
y = pred_coords[ith,1::2].detach().cpu()
plt.scatter(x,256-y,label="Prediction")

x2 = coord[ith,36:48,0].detach().cpu()
y2 = coord[ith,36:48,1].detach().cpu()
plt.scatter(x2,256-y2,label="GT")

plt.legend(loc='lower left')
plt.xlim(0,256)
plt.ylim(0,256)
# Out:
# (0.0, 256.0)

# %%
plot_heatmaps = pred_heatmaps.reshape(B,12,256,256).detach().cpu()
plot_heatmaps_all = torch.sum(plot_heatmaps,axis=1)
plt.imshow(plot_heatmaps_all[ith,:,:])

# %%
# one point
plt.imshow(plot_heatmaps[ith,0,:,:])

# %%
plt.imshow(leaf_q.reshape(num_leaf_nodes,12,256,256)[0,0,:,:].detach().cpu())

# %%
plt.imshow(leaf_q.reshape(num_leaf_nodes,12,256,256)[1,0,:,:].detach().cpu())

# %%
plt.imshow(leaf_q.reshape(num_leaf_nodes,12,256,256)[2,0,:,:].detach().cpu())

# %%
plt.imshow(leaf_q.reshape(num_leaf_nodes,12,256,256)[3,0,:,:].detach().cpu())

# %%
plt.imshow(leaf_q.reshape(num_leaf_nodes,12,256,256)[4,0,:,:].detach().cpu())

# %%
plt.imshow(leaf_q.reshape(num_leaf_nodes,12,256,256)[5,0,:,:].detach().cpu())

# %%
image = torch.sum(hm, axis=1).detach().cpu()
plt.imshow(image[ith,:,:])

# %%
plt.imshow(img[ith,:,:,:].detach().cpu().permute(1,2,0).int())
