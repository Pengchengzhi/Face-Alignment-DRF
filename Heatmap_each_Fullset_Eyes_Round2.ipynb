# %% [markdown]
# <a href="https://colab.research.google.com/github/Pengchengzhi/Face-Alignment-DRF/blob/main/Heatmap_each_Fullset_Eyes_Round2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Improve accuracy:
#
# ```
# 1. Move top1 towards top2 by 1/4
#
# ```
#
# * Ablation study
#
# ```
# 1. Anneal range (1-3 or 1-100)
# 2. Leaf Node dimension
# 3. Number of Trees
# 4. Stack Hourglass or One Hourglass
# ```

# %%
# !nvidia-smi
# Out:
# Wed Jul  7 02:33:45 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# function ConnectButton(){
#   console.log("Connect pushed"); 
#   document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click() 
# }
# setInterval(ConnectButton,60000);


# clearInterval(37042)

# %% [markdown]
# # 1. Initialize

# %%
from google.colab import drive
drive.mount("/content/drive")

import os
path="/content/drive/My Drive/Face Alignment DRF"
os.chdir(path)
os.listdir(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['Procruses Analysis.ipynb',
#  'PCA.ipynb',
#  '__pycache__',
#  'utils',
#  'datasets',
#  'Gaussian.ipynb',
#  'Heatmap_all.ipynb',
#  'trained_models',
#  'DataPreprocessing.ipynb',
#  'checkpoints',
#  'Heatmap_each.ipynb',
#  'Update_leaf.ipynb',
#  'Solve_RF_increase.ipynb',
#  'Untitled0.ipynb',
#  'Heatmap_each_Fullset_Fullpoints.ipynb']

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import os
import cv2
import json
import pandas as pd
from PIL import Image
import torchvision.models as models
import pdb
from torch.nn import Upsample
from torch.autograd import Variable
import torch.optim as optim
import time

import warnings
warnings.filterwarnings('ignore')

# %%
from utils.hourglass import *
from utils.dataloader import *

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
dim_tree = 5 # how deep the regression tree is 
num_tree = 3 # number of regression trees
variance_gaussian = 3

num_fc = int(num_tree*(2**(dim_tree-1)-1))
num_leaf_nodes = int(num_tree*2**(dim_tree-1))

# %% [markdown]
# # 2. Data Loader

# %%
helen_trainset = Helen_set(dataset_type="train",var=variance_gaussian)
train_dataloder = DataLoader(helen_trainset, batch_size=25)
# Out:
# Loading [1/2000] pictures......
# Loading [400/2000] pictures......
# Loading [800/2000] pictures......
# Loading [1200/2000] pictures......
# Loading [1600/2000] pictures......
# Loading [2000/2000] pictures......

# %%
helen_testset = Helen_set(dataset_type="test",var=variance_gaussian)
test_dataloder = DataLoader(helen_testset, batch_size=30)
# Out:
# Loading [1/330] pictures......
# Loading [200/330] pictures......

# %% [markdown]
# # 3. Pre Train

# %%
# helen_sampleset = Helen_set(dataset_type="sample")
# sample_dataloder = DataLoader(helen_sampleset, batch_size=20)

# %%
# critical = torch.nn.MSELoss()

# nIters = 200
# HGNet = HGNet().to(device)
# optimizer = optim.SGD(HGNet.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-4)

# %%
# loss_hist = torch.zeros(nIters)
# loss_epoch = torch.zeros(10)

# for iter in range(nIters):
#   for i, (x,_,y) in enumerate(sample_dataloder):
#     x = Variable(x,requires_grad=True).float().to(device)
#     y = Variable(y).float().to(device)
#     y_pred = HGNet.forward(x)
#     loss = critical(y_pred, y)
#     loss_epoch[i] = loss.item()

#     if i == 9:
#       loss_avg = torch.sum(loss_epoch)/10
#       loss_hist[iter] = loss_avg
#       if (iter+1)%10 == 0 or iter == 0:
#         print('Iter [%d/%d] loss %.4f' %(iter+1, nIters, loss_avg))
        
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()

# plt.plot(torch.arange(nIters),loss_hist.detach().numpy())
# plt.title("Training Loss")

# %%
# torch.save(HGNet.state_dict(), "/content/drive/My Drive/Face Alignment DRF/trained_models/Original_HGNet.pt")

# %% [markdown]
# # 4. Tune Training

# %% [markdown]
# ## 4.1 Functions

# %% [markdown]
# ![PHI.png](data:image/png;base64,...)

# %%
def leaf_direction(N):
  point = torch.zeros(2**N,N).to(device)

  def get01(number, len):
    result = torch.zeros(len).to(device)
    ind = len
    while ind >0:
      if 2**(ind-1)<=number:
        result[len-ind] = 1
        number -= 2**(ind-1)
      ind -= 1
    return result
  
  for i in range(2**N):
    point[i,:] = get01(i,N)

  return point.int()

# %%
def split_tree(up,here,which=0,mode='Second'):
  if mode=='initial':
    if which == 0:
      return here
    else: return (1-here)
  else:
    if which == 0:
      return up*here
    else: return up*(1-here)

# %%
def split_base(N):
  # returns index that split based on which cnn_fc col
  res = torch.zeros(2**N*N).to(device)
  lenth = 2**(N-1)
  num = 1
  left = 0
  repeat = 1
  max_repeat = 1
  while lenth>0 and repeat<2**N:
    res[left:left+lenth*2] = num
    left += lenth*2
    num += 1
    repeat -= 1
    if repeat == 0:
      lenth = int(lenth/2)
      repeat = max_repeat*2
      max_repeat = repeat
  return ((res.reshape(N,2**N)-1).T).int()

# %%
def phi(cnn_fc,mode='train'):
  N = cnn_fc.shape[0]
  out = torch.zeros(N,num_leaf_nodes).to(device)
  sigm = torch.zeros(cnn_fc.shape).to(device)

  if mode == 'test':
    sigm[cnn_fc>0] = 1
  else:
    sigm = torch.sigmoid(cnn_fc)

  direction = leaf_direction(dim_tree-1)
  tree_ind = split_base(dim_tree-1)
  X, Y = tree_ind.shape

  for ind_tree in range(num_tree):
    for x in range(X):
      for y in range(Y):
        here = sigm[:,ind_tree*(X-1)+tree_ind[x,y]]
        if y == 0:
          up = split_tree(torch.rand(3).to(device),here,which=direction[x,y],mode='initial')
        else:
          up = split_tree(up,here,which=direction[x,y])
        #print('y',y,'up',up)

      out[:,ind_tree*X+x] = up
    
  return out

# %%
def find_coord(prob_map):
  # prob_map(200,68*256*256)

  N = prob_map.shape[0]
  P = 12
  coord = torch.zeros(N,P*2).to(device)
  heatmap = prob_map.reshape(N,P,256,256).float()
  for n in range(N):
    for p in range(P):
      c1, c2 = torch.where(heatmap[n,p,:,:]==torch.max(heatmap[n,p,:,:]))
      coord[n,2*p], coord[n,2*p+1] = c1[0], c2[0]

  return coord

# %%
def get_mask(cnn_heatmaps,threshold=0.3):
  mask = torch.zeros(cnn_heatmaps.shape).to(device)
  B, P = cnn_heatmaps.shape[0:2]
  for b in range(B):
    for p in range(P):
      hm = cnn_heatmaps[b,p,:,:]
      mask[b,p,:,:][hm>torch.max(hm)*threshold]=1
  return mask

# %%
def update_iter(q, p, l):
  # q: leaf node
  # p: cnn probability
  # l: label

  gamma = torch.unsqueeze(p,2)*torch.unsqueeze(q,0) # (Ntrain,Nleaf,Nlabel)
  gamma = gamma/(torch.sum(gamma,axis=1,keepdims=True)+1e-8)
  score = torch.zeros(gamma.shape).to(q.device)
  for ll in range(q.shape[0]):
    score[:,ll,:] = l*gamma[:,ll,:]
  score = torch.sum(score,axis=0)+1e-8 # (3,2)

  return score/torch.sum(score,axis=1,keepdims=True)

# %%
def loss_ce(B, q, p, l):
  pred = torch.matmul(p,q.reshape(num_leaf_nodes,-1)).reshape(B*12,-1)
  pred = pred/torch.sum(pred,axis=1,keepdims=True)
  l = l.reshape(B*12,-1)
  l = l/torch.sum(l,axis=1,keepdims=True)

  return -criterion_KL(l,pred)

def loss_l1(q, p, l):
  return torch.sum(torch.abs(torch.matmul(p,q)-l))/l.shape[0]

def loss_alogb(B, q, p, l):
  pred = torch.matmul(p,q.reshape(num_leaf_nodes,-1)).reshape(B*12,-1)
  pred = pred/torch.sum(pred,axis=1,keepdims=True)
  l = l.reshape(B*12,-1)
  l = l/torch.sum(l,axis=1,keepdims=True)

  return -torch.sum(l*torch.log(pred))/B

# %%
# def mask_and_norm(target, mask):
#   # target (B,12,256,256)
#   # mask (B,12,256,256)
#   B,P = target.shape[0:2]

#   res = (target*mask).reshape(B,P,-1)
#   res = res/torch.sum(res,axis=2,keepdims=True)
#   return res.reshape(B,-1)

# %% [markdown]
# ## 4.2 Sample Set

# %%
# helen_sampleset = Helen_set(dataset_type="sample",var=variance_gaussian)
# sample_dataloder = DataLoader(helen_sampleset, batch_size=20) 
# helen_sampletest = Helen_set(dataset_type="sample_test",var=variance_gaussian)
# sample_test_dataloder = DataLoader(helen_sampletest, batch_size=10)

# %% [markdown]
# ## 4.3 Network

# %%
Tune_HGNet = HGNet(tune=True).to(device)
# Tune_HGNet.load_state_dict(torch.load("/content/drive/My Drive/Face Alignment DRF/trained_models/Original_HGNet.pt"))

# %%
Tune_HGNet._HGNet__lin = nn.Sequential(nn.Conv2d(128,64,1),
                    nn.BatchNorm2d(64),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(4,4),  #(64,64,64)
                    nn.Conv2d(64,16,1),
                    nn.BatchNorm2d(16),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2),  #(16,32,32)
                    nn.Conv2d(16,4,1),
                    nn.BatchNorm2d(4),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2)).to(device)  #(4,16,16)

Tune_HGNet._HGNet__tune = nn.Sequential(nn.Linear(4*16*16,num_fc)).to(device)

# %%
Tune_HGNet.load_state_dict(torch.load(os.path.join("checkpoints/Anneal_Full_Train/Tune_HGNet_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round5.pt")))
leaf_q = torch.load(os.path.join("checkpoints/Anneal_Full_Train/leaf_q_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round5.pt"))

# %% [markdown]
# ## 4.4 Training

# %%
#######################
# Initialization
Total_train = 10

# CNN initilization
nIters = 200
learning_rate = 0.01

criterion_MSE = torch.nn.MSELoss()
criterion_KL = torch.nn.KLDivLoss()
optimizer = optim.SGD(Tune_HGNet.parameters(), lr=learning_rate, momentum=0.9, weight_decay=1e-4)

# Regression Tree parameters
rf_Iters = 60

# %% [markdown]
# ### Training using L2 Loss

# %%
# Using L2 Loss

for round in range(Total_train):
  print("###########################################################")
  if torch.cuda.is_available():
    print("Round %d, Using GPU" %(round+1))
  else:
    print("Round ", round+1)
  
  #####################################
  ### Train Hourglass
  ### eyes: [36:48]
  #####################################
  if round == 0:
    leaf_q = torch.ones(num_leaf_nodes,12*256*256).to(device)/(256*256)
    cnn_Iters = 30
  else:
    cnn_Iters = nIters

  for iter in range(cnn_Iters):
    loss_epoch = 0
    for i, (x,_,y) in enumerate(sample_dataloder):
      x = x.float().to(device)
      x.requires_grad = True
      y = y.float().to(device)
      B = x.shape[0]

      outputs = Tune_HGNet.forward(x)
      cnn_prob = phi(outputs)
      cnn_heatmaps = torch.matmul(cnn_prob,leaf_q).reshape(B,12,256,256)
      # get mask for computing cnn loss
      cnn_mask = get_mask(cnn_heatmaps,threshold=0.5)
      loss = criterion_MSE(cnn_heatmaps*cnn_mask, y[:,36:48,:,:]*cnn_mask)

      loss_epoch += loss.item()
      if (iter+1)%20 == 0 or iter == 0:
        if i == 9:
          print('     CNN training, Iter [%d/%d], loss_L2: %.8f' %(iter+1, cnn_Iters, loss_epoch*224*224*1e-1))

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()


  #####################################
  ### Train Regression Trees using pinv
  #####################################
  with torch.no_grad():
    leaf_q_new = torch.zeros(num_leaf_nodes,12*256*256).to(device)
    loss0 = 0

    for i, (x,coord,y) in enumerate(sample_dataloder):
      x = x.float().to(device)
      y = y.float().to(device)
      coord = coord.float().to(device)
      B = x.shape[0]
      y_expand = y[:,36:48,:,:].reshape(B,-1) #(200,12*256*256)

      outputs = Tune_HGNet.forward(x)
      cnn_prob = phi(outputs)

      pred_coord0 = find_coord(torch.matmul(cnn_prob,leaf_q))
      loss0 += torch.sum(torch.abs(pred_coord0-coord[:,36:48,:].reshape(B,-1)))

      leaf_q_new += torch.matmul(torch.linalg.pinv(cnn_prob), y_expand) #(8,12*256*256)

    leaf_q = leaf_q_new/10  # average among each bach
    leaf_q = torch.abs(leaf_q.reshape(num_leaf_nodes,12,-1)) #(B,12,256*256)
    leaf_q = leaf_q/torch.sum(leaf_q, axis=2, keepdims=True)
    for nleaf in range(num_leaf_nodes):
      for npoints in range(12):
        leaf_q[nleaf,npoints,:][leaf_q[nleaf,npoints,:] <= torch.max(leaf_q[nleaf,npoints,:])*0.2] = 0
    leaf_q = leaf_q/torch.sum(leaf_q, axis=2, keepdims=True)
    leaf_q = leaf_q.reshape(num_leaf_nodes,-1)

    print("     RF training, coordinate loss: %.4f" %(loss0/10))
# Out:
# ###########################################################
# Round 1, Using GPU
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-5080c6c81955> in <module>()
#      20   for iter in range(cnn_Iters):
#      21     loss_epoch = 0
# ---> 22     for i, (x,_,y) in enumerate(sample_dataloder):
#      23       x = x.float().to(device)
#      24       x.requires_grad = True
#
# NameError: name 'sample_dataloder' is not defined

# %% [markdown]
# ### Training using Log likelihood

# %%
# update using log likelihood

time_initial = time.time()
for round in range(5,11):
  time_start = time.time()
  print("############################################################################")
  if torch.cuda.is_available():
    print("Round [%d/%d], Using GPU" %(round+1, Total_train))
  else:
    print("Round [%d/%d]" %(round+1, Total_train))

  
  ######################################################
  ### Train Hourglass using gradient decent
  ### eyes: [36:48]
  ######################################################
  if round == 0:
    leaf_q = torch.ones(num_leaf_nodes,12,256*256).to(device)/(256*256)
    cnn_Iters = 30
  else:
    cnn_Iters = nIters

  for iter in range(cnn_Iters):
    loss_epoch = 0
    for i, (x,_,y) in enumerate(train_dataloder):
      x = x.float().to(device)
      x.requires_grad = True
      y = y.float().to(device)
      B = x.shape[0]

      outputs = Tune_HGNet.forward(x)*(round*0.2+1)
      cnn_prob = phi(outputs)

      cnn_heatmaps = torch.matmul(cnn_prob,leaf_q.reshape(num_leaf_nodes,-1)).reshape(B*12,-1)
      cnn_heatmaps = cnn_heatmaps/torch.sum(cnn_heatmaps,axis=1,keepdims=True)
      label_heatmaps = y[:,36:48,:,:].reshape(B*12,-1)
      label_heatmaps = label_heatmaps/torch.sum(label_heatmaps,axis=1,keepdims=True)
      #loss = -criterion_KL(cnn_heatmaps,label_heatmaps)
      loss = -torch.sum(label_heatmaps*torch.log(cnn_heatmaps+1e-8))/B

      loss_epoch += loss.item()
      if (iter+1)%5 == 0 or iter == 0:
        if i == 79:
          loss_epoch = loss_epoch/80
          print('     CNN training, Iter [%d/%d], loss_CE: %.4f' %(iter+1, cnn_Iters, loss_epoch))

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

  # calculate time for CNN training
  time_cnn = time.time()
  print("     -----> CNN training time: ## %.2f mins ## " %((time_cnn-time_start)/60))

  # plot the face after CNN training
  # Does not select
  cnn_heatmaps = torch.matmul(cnn_prob,leaf_q.reshape(num_leaf_nodes,-1)).reshape(B,12,-1)
  first_face = torch.sum(cnn_heatmaps[0,:,:],axis=0)
  first_face = first_face/torch.sum(first_face)
  plt.imshow(first_face.reshape(256,256).detach().cpu())
  plt.title("Anneal: Round"+str(round+1)+"_CNN Full")
  plt.savefig(os.path.join("checkpoints/Anneal_Full_Train_V100/var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+"_CNN_Full.png"))
  plt.show()

  # Selcet
  cnn_prob_test = phi(outputs, mode='test')
  cnn_heatmaps = torch.matmul(cnn_prob_test,leaf_q.reshape(num_leaf_nodes,-1)).reshape(B,12,-1)
  first_face = torch.sum(cnn_heatmaps[0,:,:],axis=0)
  first_face = first_face/torch.sum(first_face)
  plt.imshow(first_face.reshape(256,256).detach().cpu())
  plt.title("Anneal: Round"+str(round+1)+"_CNN Select")
  plt.savefig(os.path.join("checkpoints/Anneal_Full_Train_V100/var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+"_CNN_Select.png"))
  plt.show()

  ######################################################
  ### Train Regression Trees using variational bounding
  ######################################################
  with torch.no_grad():
    loss0,loss_select = 0,0
    leaf_q = leaf_q.reshape(num_leaf_nodes,12,256*256)
    new_leaf_q = torch.zeros(leaf_q.shape).to(device)

    for i, (x,coord,y) in enumerate(train_dataloder):
      next_leaf_q = leaf_q.clone()
      x = x.float().to(device)
      y = y.float().to(device)
      coord = coord.float().to(device)
      B = x.shape[0]
      y_expand = y[:,36:48,:,:].reshape(B,12,-1) #(200,12*256*256)

      outputs = Tune_HGNet.forward(x)*(round*0.2+1)
      cnn_prob = phi(outputs)
      cnn_prob_select = phi(outputs, mode='test')
  
      for rf_iter in range(rf_Iters):
        for points_id in range(12):
          next_leaf_q[:,points_id,:] = update_iter(next_leaf_q[:,points_id,:], cnn_prob, y_expand[:,points_id,:])
        if ((i+1)%15 == 0 or i == 0) and ((rf_iter+1)%10 == 0 or rf_iter == 0):
          rf_loss_CE = loss_alogb(B, next_leaf_q, cnn_prob, y_expand)
          print("     RF training, Batch %d, rf_iter [%d/%d], loss_CE: %.4f" %(i+1, rf_iter+1, rf_Iters, rf_loss_CE))

      # Calculate loss
      pred_coord0 = find_coord(torch.matmul(cnn_prob,next_leaf_q.reshape(num_leaf_nodes,-1)))
      loss0 += torch.sum(torch.abs(pred_coord0-coord[:,36:48,:].reshape(B,-1)))/B
      pred_coord_select = find_coord(torch.matmul(cnn_prob_select,next_leaf_q.reshape(num_leaf_nodes,-1)))
      loss_select += torch.sum(torch.abs(pred_coord_select-coord[:,36:48,:].reshape(B,-1)))/B

      # update leaf node
      new_leaf_q += next_leaf_q
    leaf_q = new_leaf_q/torch.sum(new_leaf_q, axis=2, keepdims=True)
    


  # plot the face after rf training
  # Does not select
  rf_heatmaps = torch.matmul(cnn_prob,leaf_q.reshape(num_leaf_nodes,-1)).reshape(B,12,-1)
  first_face = torch.sum(rf_heatmaps[0,:,:],axis=0)
  first_face = first_face/torch.sum(first_face)
  plt.imshow(first_face.reshape(256,256).detach().cpu())
  plt.title("Anneal: Round"+str(round+1)+"_RF Full")
  plt.savefig(os.path.join("checkpoints/Anneal_Full_Train_V100/var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+"_RF_Full.png"))
  plt.show()

  # Select
  cnn_prob_test = phi(outputs, mode='test')
  rf_heatmaps = torch.matmul(cnn_prob_test,leaf_q.reshape(num_leaf_nodes,-1)).reshape(B,12,-1)
  first_face = torch.sum(rf_heatmaps[0,:,:],axis=0)
  first_face = first_face/torch.sum(first_face)
  plt.imshow(first_face.reshape(256,256).detach().cpu())
  plt.title("Anneal: Round"+str(round+1)+"_RF Select")
  plt.savefig(os.path.join("checkpoints/Anneal_Full_Train_V100/var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+"_RF_Select.png"))
  plt.show()

  print("     RF training, coordinate loss: %.2f, after selcetion: %.2f" %(loss0/80, loss_select/80))

  # save parameters for this round
  torch.save(Tune_HGNet.state_dict(), os.path.join("checkpoints/Anneal_Full_Train_V100/Tune_HGNet_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+'.pt'))
  torch.save(leaf_q, os.path.join("checkpoints/Anneal_Full_Train_V100/leaf_q_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+'.pt'))

  # calculate time for rf training
  time_rf = time.time()
  print("     -----> RF training time: ## %.2f mins ## " %((time_rf-time_cnn)/60))
  print("     -----> Training time for this round: ## %.2f mins ## " %((time_rf-time_start)/60))

# Finish Training
torch.save(Tune_HGNet.state_dict(), os.path.join("checkpoints/Anneal_Full_Train_V100/Tune_HGNet_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_final.pt"))
torch.save(leaf_q, os.path.join("checkpoints/Anneal_Full_Train_V100/leaf_q_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_final.pt"))

# calculate total training time
time_end = time.time()
print("-----> Total training time: ## %.2f hrs ## " %((time_end-time_initial)/3600))
# Out:
# ############################################################################
# Round [6/10], Using GPU
#      CNN training, Iter [1/200], loss_CE: 80.5942
#      CNN training, Iter [5/200], loss_CE: 80.5447
#      CNN training, Iter [10/200], loss_CE: 80.5344
#      CNN training, Iter [15/200], loss_CE: 80.5210
#      CNN training, Iter [20/200], loss_CE: 80.5158
#      CNN training, Iter [25/200], loss_CE: 80.5082
#      CNN training, Iter [30/200], loss_CE: 80.5048
#      CNN training, Iter [35/200], loss_CE: 80.4905
#      CNN training, Iter [40/200], loss_CE: 80.4927
#      CNN training, Iter [45/200], loss_CE: 80.4956
#      CNN training, Iter [50/200], loss_CE: 80.4881
#      CNN training, Iter [55/200], loss_CE: 80.4868
#      CNN training, Iter [60/200], loss_CE: 80.4793
#      CNN training, Iter [65/200], loss_CE: 80.4766
#      CNN training, Iter [70/200], loss_CE: 80.4760
#      CNN training, Iter [75/200], loss_CE: 80.4734
#      CNN training, Iter [80/200], loss_CE: 80.4712
#      CNN training, Iter [85/200], loss_CE: 80.4753
#      CNN training, Iter [90/200], loss_CE: 80.4779
#      CNN training, Iter [95/200], loss_CE: 80.4734
#      CNN training, Iter [100/200], loss_CE: 80.4711
#      CNN training, Iter [105/200], loss_CE: 80.4737
#      CNN training, Iter [110/200], loss_CE: 80.4741
#      CNN training, Iter [115/200], loss_CE: 80.4722
#      CNN training, Iter [120/200], loss_CE: 80.4638
#      CNN training, Iter [125/200], loss_CE: 80.4620
#      CNN training, Iter [130/200], loss_CE: 80.4590
#      CNN training, Iter [135/200], loss_CE: 80.4599
#      CNN training, Iter [140/200], loss_CE: 80.4578
#      CNN training, Iter [145/200], loss_CE: 80.4649
#      CNN training, Iter [150/200], loss_CE: 80.4664
#      CNN training, Iter [155/200], loss_CE: 80.4636
#      CNN training, Iter [160/200], loss_CE: 80.4645
#      CNN training, Iter [165/200], loss_CE: 80.4607
#      CNN training, Iter [170/200], loss_CE: 80.4613
#      CNN training, Iter [175/200], loss_CE: 80.4583
#      CNN training, Iter [180/200], loss_CE: 80.4617
#      CNN training, Iter [185/200], loss_CE: 80.4571
#      CNN training, Iter [190/200], loss_CE: 80.4555
#      CNN training, Iter [195/200], loss_CE: 80.4558
#      CNN training, Iter [200/200], loss_CE: 80.4561
#      -----> CNN training time: ## 156.70 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_CE: 67.5922
#      RF training, Batch 1, rf_iter [10/60], loss_CE: 66.6565
#      RF training, Batch 1, rf_iter [20/60], loss_CE: 66.5978
#      RF training, Batch 1, rf_iter [30/60], loss_CE: 66.5832
#      RF training, Batch 1, rf_iter [40/60], loss_CE: 66.5769
#      RF training, Batch 1, rf_iter [50/60], loss_CE: 66.5735
#      RF training, Batch 1, rf_iter [60/60], loss_CE: 66.5713
#      RF training, Batch 15, rf_iter [1/60], loss_CE: 67.8727
#      RF training, Batch 15, rf_iter [10/60], loss_CE: 66.7839
#      RF training, Batch 15, rf_iter [20/60], loss_CE: 66.7250
#      RF training, Batch 15, rf_iter [30/60], loss_CE: 66.7107
#      RF training, Batch 15, rf_iter [40/60], loss_CE: 66.7052
#      RF training, Batch 15, rf_iter [50/60], loss_CE: 66.7024
#      RF training, Batch 15, rf_iter [60/60], loss_CE: 66.7008
#      RF training, Batch 30, rf_iter [1/60], loss_CE: 68.2296
#      RF training, Batch 30, rf_iter [10/60], loss_CE: 67.0292
#      RF training, Batch 30, rf_iter [20/60], loss_CE: 66.9663
#      RF training, Batch 30, rf_iter [30/60], loss_CE: 66.9538
#      RF training, Batch 30, rf_iter [40/60], loss_CE: 66.9494
#      RF training, Batch 30, rf_iter [50/60], loss_CE: 66.9473
#      RF training, Batch 30, rf_iter [60/60], loss_CE: 66.9462
#      RF training, Batch 45, rf_iter [1/60], loss_CE: 67.5707
#      RF training, Batch 45, rf_iter [10/60], loss_CE: 66.2999
#      RF training, Batch 45, rf_iter [20/60], loss_CE: 66.2291
#      RF training, Batch 45, rf_iter [30/60], loss_CE: 66.2136
#      RF training, Batch 45, rf_iter [40/60], loss_CE: 66.2073
#      RF training, Batch 45, rf_iter [50/60], loss_CE: 66.2041
#      RF training, Batch 45, rf_iter [60/60], loss_CE: 66.2023
#      RF training, Batch 60, rf_iter [1/60], loss_CE: 69.0562
#      RF training, Batch 60, rf_iter [10/60], loss_CE: 67.7253
#      RF training, Batch 60, rf_iter [20/60], loss_CE: 67.6479
#      RF training, Batch 60, rf_iter [30/60], loss_CE: 67.6282
#      RF training, Batch 60, rf_iter [40/60], loss_CE: 67.6210
#      RF training, Batch 60, rf_iter [50/60], loss_CE: 67.6176
#      RF training, Batch 60, rf_iter [60/60], loss_CE: 67.6157
#      RF training, Batch 75, rf_iter [1/60], loss_CE: 68.0745
#      RF training, Batch 75, rf_iter [10/60], loss_CE: 66.9561
#      RF training, Batch 75, rf_iter [20/60], loss_CE: 66.8894
#      RF training, Batch 75, rf_iter [30/60], loss_CE: 66.8702
#      RF training, Batch 75, rf_iter [40/60], loss_CE: 66.8618
#      RF training, Batch 75, rf_iter [50/60], loss_CE: 66.8574
#      RF training, Batch 75, rf_iter [60/60], loss_CE: 66.8548
#      RF training, coordinate loss: 49.85, after selcetion: 58.97
#      -----> RF training time: ## 101.91 mins ##
#      -----> Training time for this round: ## 258.61 mins ##
# ############################################################################
# Round [7/10], Using GPU
#      CNN training, Iter [1/200], loss_CE: 80.2228
#      CNN training, Iter [5/200], loss_CE: 80.1956
#      CNN training, Iter [10/200], loss_CE: 80.1876
#      CNN training, Iter [15/200], loss_CE: 80.1884
#      CNN training, Iter [20/200], loss_CE: 80.1841
#      CNN training, Iter [25/200], loss_CE: 80.1695
#      CNN training, Iter [30/200], loss_CE: 80.1633
#      CNN training, Iter [35/200], loss_CE: 80.1659
#      CNN training, Iter [40/200], loss_CE: 80.1675
#      CNN training, Iter [45/200], loss_CE: 80.1611
#      CNN training, Iter [50/200], loss_CE: 80.1554
#      CNN training, Iter [55/200], loss_CE: 80.1512
#      CNN training, Iter [60/200], loss_CE: 80.1516
#      CNN training, Iter [65/200], loss_CE: 80.1564
#      CNN training, Iter [70/200], loss_CE: 80.1553
#      CNN training, Iter [75/200], loss_CE: 80.1492
#      CNN training, Iter [80/200], loss_CE: 80.1419
#      CNN training, Iter [85/200], loss_CE: 80.1469
#      CNN training, Iter [90/200], loss_CE: 80.1487
#      CNN training, Iter [95/200], loss_CE: 80.1449
#      CNN training, Iter [100/200], loss_CE: 80.1387
#      CNN training, Iter [105/200], loss_CE: 80.1420
#      CNN training, Iter [110/200], loss_CE: 80.1412
#      CNN training, Iter [115/200], loss_CE: 80.1416
#      CNN training, Iter [120/200], loss_CE: 80.1406
#      CNN training, Iter [125/200], loss_CE: 80.1357
#      CNN training, Iter [130/200], loss_CE: 80.1327
#      CNN training, Iter [135/200], loss_CE: 80.1377
#      CNN training, Iter [140/200], loss_CE: 80.1392
#      CNN training, Iter [145/200], loss_CE: 80.1378
#      CNN training, Iter [150/200], loss_CE: 80.1308
#      CNN training, Iter [155/200], loss_CE: 80.1381
#      CNN training, Iter [160/200], loss_CE: 80.1374
#      CNN training, Iter [165/200], loss_CE: 80.1339
#      CNN training, Iter [170/200], loss_CE: 80.1256
#      CNN training, Iter [175/200], loss_CE: 80.1288
#      CNN training, Iter [180/200], loss_CE: 80.1296
#      CNN training, Iter [185/200], loss_CE: 80.1261
#      CNN training, Iter [190/200], loss_CE: 80.1299
#      CNN training, Iter [195/200], loss_CE: 80.1317
#      CNN training, Iter [200/200], loss_CE: 80.1338
#      -----> CNN training time: ## 149.50 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_CE: 67.3933
#      RF training, Batch 1, rf_iter [10/60], loss_CE: 66.4136
#      RF training, Batch 1, rf_iter [20/60], loss_CE: 66.3471
#      RF training, Batch 1, rf_iter [30/60], loss_CE: 66.3319
#      RF training, Batch 1, rf_iter [40/60], loss_CE: 66.3260
#      RF training, Batch 1, rf_iter [50/60], loss_CE: 66.3229
#      RF training, Batch 1, rf_iter [60/60], loss_CE: 66.3211
#      RF training, Batch 15, rf_iter [1/60], loss_CE: 67.8695
#      RF training, Batch 15, rf_iter [10/60], loss_CE: 66.7825
#      RF training, Batch 15, rf_iter [20/60], loss_CE: 66.7304
#      RF training, Batch 15, rf_iter [30/60], loss_CE: 66.7173
#      RF training, Batch 15, rf_iter [40/60], loss_CE: 66.7122
#      RF training, Batch 15, rf_iter [50/60], loss_CE: 66.7095
#      RF training, Batch 15, rf_iter [60/60], loss_CE: 66.7078
#      RF training, Batch 30, rf_iter [1/60], loss_CE: 67.9042
#      RF training, Batch 30, rf_iter [10/60], loss_CE: 66.8076
#      RF training, Batch 30, rf_iter [20/60], loss_CE: 66.7561
#      RF training, Batch 30, rf_iter [30/60], loss_CE: 66.7449
#      RF training, Batch 30, rf_iter [40/60], loss_CE: 66.7405
#      RF training, Batch 30, rf_iter [50/60], loss_CE: 66.7383
#      RF training, Batch 30, rf_iter [60/60], loss_CE: 66.7369
#      RF training, Batch 45, rf_iter [1/60], loss_CE: 67.2133
#      RF training, Batch 45, rf_iter [10/60], loss_CE: 66.1321
#      RF training, Batch 45, rf_iter [20/60], loss_CE: 66.0736
#      RF training, Batch 45, rf_iter [30/60], loss_CE: 66.0577
#      RF training, Batch 45, rf_iter [40/60], loss_CE: 66.0508
#      RF training, Batch 45, rf_iter [50/60], loss_CE: 66.0472
#      RF training, Batch 45, rf_iter [60/60], loss_CE: 66.0451
#      RF training, Batch 60, rf_iter [1/60], loss_CE: 69.1770
#      RF training, Batch 60, rf_iter [10/60], loss_CE: 67.7348
#      RF training, Batch 60, rf_iter [20/60], loss_CE: 67.6548
#      RF training, Batch 60, rf_iter [30/60], loss_CE: 67.6373
#      RF training, Batch 60, rf_iter [40/60], loss_CE: 67.6309
#      RF training, Batch 60, rf_iter [50/60], loss_CE: 67.6278
#      RF training, Batch 60, rf_iter [60/60], loss_CE: 67.6261
#      RF training, Batch 75, rf_iter [1/60], loss_CE: 68.1970
#      RF training, Batch 75, rf_iter [10/60], loss_CE: 67.1247
#      RF training, Batch 75, rf_iter [20/60], loss_CE: 67.0591
#      RF training, Batch 75, rf_iter [30/60], loss_CE: 67.0416
#      RF training, Batch 75, rf_iter [40/60], loss_CE: 67.0342
#      RF training, Batch 75, rf_iter [50/60], loss_CE: 67.0302
#      RF training, Batch 75, rf_iter [60/60], loss_CE: 67.0278
#      RF training, coordinate loss: 48.38, after selcetion: 59.85
#      -----> RF training time: ## 101.84 mins ##
#      -----> Training time for this round: ## 251.34 mins ##
# ############################################################################
# Round [8/10], Using GPU
#      CNN training, Iter [1/200], loss_CE: 80.0034
#      CNN training, Iter [5/200], loss_CE: 79.9920
#      CNN training, Iter [10/200], loss_CE: 79.9837
#      CNN training, Iter [15/200], loss_CE: 79.9806
#      CNN training, Iter [20/200], loss_CE: 79.9727
#      CNN training, Iter [25/200], loss_CE: 79.9760
#      CNN training, Iter [30/200], loss_CE: 79.9779
#      CNN training, Iter [35/200], loss_CE: 79.9786
#      CNN training, Iter [40/200], loss_CE: 79.9753
#      CNN training, Iter [45/200], loss_CE: 79.9703
#      CNN training, Iter [50/200], loss_CE: 79.9673
#      CNN training, Iter [55/200], loss_CE: 79.9697
#      CNN training, Iter [60/200], loss_CE: 79.9634
#      CNN training, Iter [65/200], loss_CE: 79.9663
#      CNN training, Iter [70/200], loss_CE: 79.9660
#      CNN training, Iter [75/200], loss_CE: 79.9692
#      CNN training, Iter [80/200], loss_CE: 79.9626
#      CNN training, Iter [85/200], loss_CE: 79.9610
#      CNN training, Iter [90/200], loss_CE: 79.9604
#      CNN training, Iter [95/200], loss_CE: 79.9595
#      CNN training, Iter [100/200], loss_CE: 79.9573
#      CNN training, Iter [105/200], loss_CE: 79.9603
#      CNN training, Iter [110/200], loss_CE: 79.9641
#      CNN training, Iter [115/200], loss_CE: 79.9573
#      CNN training, Iter [120/200], loss_CE: 79.9552
#      CNN training, Iter [125/200], loss_CE: 79.9631
#      CNN training, Iter [130/200], loss_CE: 79.9563
#      CNN training, Iter [135/200], loss_CE: 79.9532
#      CNN training, Iter [140/200], loss_CE: 79.9531
#      CNN training, Iter [145/200], loss_CE: 79.9583
#      CNN training, Iter [150/200], loss_CE: 79.9563
#      CNN training, Iter [155/200], loss_CE: 79.9505
#      CNN training, Iter [160/200], loss_CE: 79.9556
#      CNN training, Iter [165/200], loss_CE: 79.9535
#      CNN training, Iter [170/200], loss_CE: 79.9528
#      CNN training, Iter [175/200], loss_CE: 79.9513
#      CNN training, Iter [180/200], loss_CE: 79.9512
#      CNN training, Iter [185/200], loss_CE: 79.9530
#      CNN training, Iter [190/200], loss_CE: 79.9517
#      CNN training, Iter [195/200], loss_CE: 79.9552
#      CNN training, Iter [200/200], loss_CE: 79.9477
#      -----> CNN training time: ## 151.00 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_CE: 67.4111
#      RF training, Batch 1, rf_iter [10/60], loss_CE: 66.3518
#      RF training, Batch 1, rf_iter [20/60], loss_CE: 66.2818
#      RF training, Batch 1, rf_iter [30/60], loss_CE: 66.2647
#      RF training, Batch 1, rf_iter [40/60], loss_CE: 66.2577
#      RF training, Batch 1, rf_iter [50/60], loss_CE: 66.2541
#      RF training, Batch 1, rf_iter [60/60], loss_CE: 66.2520
#      RF training, Batch 15, rf_iter [1/60], loss_CE: 67.9535
#      RF training, Batch 15, rf_iter [10/60], loss_CE: 66.8590
#      RF training, Batch 15, rf_iter [20/60], loss_CE: 66.8062
#      RF training, Batch 15, rf_iter [30/60], loss_CE: 66.7921
#      RF training, Batch 15, rf_iter [40/60], loss_CE: 66.7862
#      RF training, Batch 15, rf_iter [50/60], loss_CE: 66.7832
#      RF training, Batch 15, rf_iter [60/60], loss_CE: 66.7814
#      RF training, Batch 30, rf_iter [1/60], loss_CE: 68.0855
#      RF training, Batch 30, rf_iter [10/60], loss_CE: 66.8810
#      RF training, Batch 30, rf_iter [20/60], loss_CE: 66.8195
#      RF training, Batch 30, rf_iter [30/60], loss_CE: 66.8060
#      RF training, Batch 30, rf_iter [40/60], loss_CE: 66.8009
#      RF training, Batch 30, rf_iter [50/60], loss_CE: 66.7984
#      RF training, Batch 30, rf_iter [60/60], loss_CE: 66.7970
#      RF training, Batch 45, rf_iter [1/60], loss_CE: 66.9057
#      RF training, Batch 45, rf_iter [10/60], loss_CE: 65.8523
#      RF training, Batch 45, rf_iter [20/60], loss_CE: 65.7884
#      RF training, Batch 45, rf_iter [30/60], loss_CE: 65.7716
#      RF training, Batch 45, rf_iter [40/60], loss_CE: 65.7647
#      RF training, Batch 45, rf_iter [50/60], loss_CE: 65.7612
#      RF training, Batch 45, rf_iter [60/60], loss_CE: 65.7592
#      RF training, Batch 60, rf_iter [1/60], loss_CE: 68.8693
#      RF training, Batch 60, rf_iter [10/60], loss_CE: 67.7424
#      RF training, Batch 60, rf_iter [20/60], loss_CE: 67.6642
#      RF training, Batch 60, rf_iter [30/60], loss_CE: 67.6451
#      RF training, Batch 60, rf_iter [40/60], loss_CE: 67.6374
#      RF training, Batch 60, rf_iter [50/60], loss_CE: 67.6335
#      RF training, Batch 60, rf_iter [60/60], loss_CE: 67.6312
#      RF training, Batch 75, rf_iter [1/60], loss_CE: 67.7893
#      RF training, Batch 75, rf_iter [10/60], loss_CE: 66.6242
#      RF training, Batch 75, rf_iter [20/60], loss_CE: 66.5614
#      RF training, Batch 75, rf_iter [30/60], loss_CE: 66.5463
#      RF training, Batch 75, rf_iter [40/60], loss_CE: 66.5403
#      RF training, Batch 75, rf_iter [50/60], loss_CE: 66.5374
#      RF training, Batch 75, rf_iter [60/60], loss_CE: 66.5357
#      RF training, coordinate loss: 47.02, after selcetion: 57.90
#      -----> RF training time: ## 101.23 mins ##
#      -----> Training time for this round: ## 252.24 mins ##
# ############################################################################
# Round [9/10], Using GPU
#      CNN training, Iter [1/200], loss_CE: 79.9174
#      CNN training, Iter [5/200], loss_CE: 79.9150
#      CNN training, Iter [10/200], loss_CE: 79.9084
#      CNN training, Iter [15/200], loss_CE: 79.9001
#      CNN training, Iter [20/200], loss_CE: 79.8994
#      CNN training, Iter [25/200], loss_CE: 79.9033
#      CNN training, Iter [30/200], loss_CE: 79.9030
#      CNN training, Iter [35/200], loss_CE: 79.9001
#      CNN training, Iter [40/200], loss_CE: 79.8989
#      CNN training, Iter [45/200], loss_CE: 79.9021
#      CNN training, Iter [50/200], loss_CE: 79.8999
#      CNN training, Iter [55/200], loss_CE: 79.8979
#      CNN training, Iter [60/200], loss_CE: 79.8969
#      CNN training, Iter [65/200], loss_CE: 79.8947
#      CNN training, Iter [70/200], loss_CE: 79.8905
#      CNN training, Iter [75/200], loss_CE: 79.8962
#      CNN training, Iter [80/200], loss_CE: 79.8944
#      CNN training, Iter [85/200], loss_CE: 79.8954
#      CNN training, Iter [90/200], loss_CE: 79.8893
#      CNN training, Iter [95/200], loss_CE: 79.8911
#      CNN training, Iter [100/200], loss_CE: 79.8955
#      CNN training, Iter [105/200], loss_CE: 79.8920
#      CNN training, Iter [110/200], loss_CE: 79.8888
#      CNN training, Iter [115/200], loss_CE: 79.8883
#      CNN training, Iter [120/200], loss_CE: 79.8891
#      CNN training, Iter [125/200], loss_CE: 79.8852
#      CNN training, Iter [130/200], loss_CE: 79.8871
#      CNN training, Iter [135/200], loss_CE: 79.8815
#      CNN training, Iter [140/200], loss_CE: 79.8824
#      CNN training, Iter [145/200], loss_CE: 79.8870
#      CNN training, Iter [150/200], loss_CE: 79.8843
#      CNN training, Iter [155/200], loss_CE: 79.8878
#      CNN training, Iter [160/200], loss_CE: 79.8853
#      CNN training, Iter [165/200], loss_CE: 79.8819
#      CNN training, Iter [170/200], loss_CE: 79.8786
#      CNN training, Iter [175/200], loss_CE: 79.8916
#      CNN training, Iter [180/200], loss_CE: 79.8855
#      CNN training, Iter [185/200], loss_CE: 79.8839
#      CNN training, Iter [190/200], loss_CE: 79.8796
#      CNN training, Iter [195/200], loss_CE: 79.8829
#      CNN training, Iter [200/200], loss_CE: 79.8873
#      -----> CNN training time: ## 149.44 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_CE: 67.2710
#      RF training, Batch 1, rf_iter [10/60], loss_CE: 66.1913
#      RF training, Batch 1, rf_iter [20/60], loss_CE: 66.1234
#      RF training, Batch 1, rf_iter [30/60], loss_CE: 66.1091
#      RF training, Batch 1, rf_iter [40/60], loss_CE: 66.1039
#      RF training, Batch 1, rf_iter [50/60], loss_CE: 66.1013
#      RF training, Batch 1, rf_iter [60/60], loss_CE: 66.0998
#      RF training, Batch 15, rf_iter [1/60], loss_CE: 67.9903
#      RF training, Batch 15, rf_iter [10/60], loss_CE: 66.8928
#      RF training, Batch 15, rf_iter [20/60], loss_CE: 66.8321
#      RF training, Batch 15, rf_iter [30/60], loss_CE: 66.8169
#      RF training, Batch 15, rf_iter [40/60], loss_CE: 66.8110
#      RF training, Batch 15, rf_iter [50/60], loss_CE: 66.8081
#      RF training, Batch 15, rf_iter [60/60], loss_CE: 66.8065
#      RF training, Batch 30, rf_iter [1/60], loss_CE: 67.9825
#      RF training, Batch 30, rf_iter [10/60], loss_CE: 66.8150
#      RF training, Batch 30, rf_iter [20/60], loss_CE: 66.7507
#      RF training, Batch 30, rf_iter [30/60], loss_CE: 66.7341
#      RF training, Batch 30, rf_iter [40/60], loss_CE: 66.7277
#      RF training, Batch 30, rf_iter [50/60], loss_CE: 66.7245
#      RF training, Batch 30, rf_iter [60/60], loss_CE: 66.7228
#      RF training, Batch 45, rf_iter [1/60], loss_CE: 67.0092
#      RF training, Batch 45, rf_iter [10/60], loss_CE: 65.8963
#      RF training, Batch 45, rf_iter [20/60], loss_CE: 65.8367
#      RF training, Batch 45, rf_iter [30/60], loss_CE: 65.8209
#      RF training, Batch 45, rf_iter [40/60], loss_CE: 65.8142
#      RF training, Batch 45, rf_iter [50/60], loss_CE: 65.8108
#      RF training, Batch 45, rf_iter [60/60], loss_CE: 65.8087
#      RF training, Batch 60, rf_iter [1/60], loss_CE: 68.5194
#      RF training, Batch 60, rf_iter [10/60], loss_CE: 67.3307
#      RF training, Batch 60, rf_iter [20/60], loss_CE: 67.2545
#      RF training, Batch 60, rf_iter [30/60], loss_CE: 67.2361
#      RF training, Batch 60, rf_iter [40/60], loss_CE: 67.2287
#      RF training, Batch 60, rf_iter [50/60], loss_CE: 67.2249
#      RF training, Batch 60, rf_iter [60/60], loss_CE: 67.2226
#      RF training, Batch 75, rf_iter [1/60], loss_CE: 67.6329
#      RF training, Batch 75, rf_iter [10/60], loss_CE: 66.5501
#      RF training, Batch 75, rf_iter [20/60], loss_CE: 66.4894
#      RF training, Batch 75, rf_iter [30/60], loss_CE: 66.4755
#      RF training, Batch 75, rf_iter [40/60], loss_CE: 66.4703
#      RF training, Batch 75, rf_iter [50/60], loss_CE: 66.4676
#      RF training, Batch 75, rf_iter [60/60], loss_CE: 66.4661
#      RF training, coordinate loss: 46.37, after selcetion: 56.84
#      -----> RF training time: ## 100.68 mins ##
#      -----> Training time for this round: ## 250.12 mins ##
# ############################################################################
# Round [10/10], Using GPU
#      CNN training, Iter [1/200], loss_CE: 79.7991
#      CNN training, Iter [5/200], loss_CE: 79.7852
#      CNN training, Iter [10/200], loss_CE: 79.7863
#      CNN training, Iter [15/200], loss_CE: 79.7870

# %%
for ith in range(20):
  px = pred_coord0[ith,::2].detach().cpu()
  py = pred_coord0[ith,1::2].detach().cpu()

  lx = coord[ith,36:48,0].detach().cpu()
  ly = coord[ith,36:48,1].detach().cpu()

  plt.scatter(lx,256-ly,label='Label')
  plt.scatter(px,256-py,label='Prediction')

  plt.xlim(0,256)
  plt.ylim(0,256)
  plt.title(str(ith)+"th Train Sample - Full")
  plt.legend(loc='lower left')
  plt.show()

# %%
for ith in range(20):
  px = pred_coord_select[ith,::2].detach().cpu()
  py = pred_coord-select[ith,1::2].detach().cpu()

  lx = coord[ith,36:48,0].detach().cpu()
  ly = coord[ith,36:48,1].detach().cpu()

  plt.scatter(lx,256-ly,label='Label')
  plt.scatter(px,256-py,label='Prediction')

  plt.xlim(0,256)
  plt.ylim(0,256)
  plt.title(str(ith)+"th Train Sample - Select")
  plt.legend(loc='lower left')
  plt.show()

# %% [markdown]
# ## 4.5 Test

# %% [markdown]
# ### Restore from saved weights

# %%
Tune_HGNet = HGNet(tune=True).to(device)
Tune_HGNet._HGNet__lin = nn.Sequential(nn.Conv2d(128,64,1),
                    nn.BatchNorm2d(64),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(4,4),  #(64,64,64)
                    nn.Conv2d(64,16,1),
                    nn.BatchNorm2d(16),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2),  #(16,32,32)
                    nn.Conv2d(16,4,1),
                    nn.BatchNorm2d(4),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2)).to(device)  #(4,16,16)

Tune_HGNet._HGNet__tune = nn.Sequential(nn.Linear(4*16*16,num_fc)).to(device)

Tune_HGNet.load_state_dict(torch.load(os.path.join("checkpoints/Anneal_Full_Train/Tune_HGNet_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round5.pt")))
leaf_q = torch.load(os.path.join("checkpoints/Anneal_Full_Train/leaf_q_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round5.pt"))

# %%
# import torchsummary
# def count_parameters(model):
#   return sum(p.numel() for p in model.parameters() if p.requires_grad)
# torchsummary.summary(Tune_HGNet, (3,256,256))
# print('parameters_count:',count_parameters(Tune_HGNet))

# %% [markdown]
# ### Test

# %%
def NME_eye(pred_coord, label_coord):
  # pred_coord(B,12*2)
  x = pred_coord[:,::2]
  y = pred_coord[:,1::2]
  x_label = label_coord[:,::2]
  y_label = label_coord[:,1::2]

  x_center_left = torch.sum(x[:,0:6],axis=1,keepdims=True)/6
  x_center_right = torch.sum(x[:,6:12],axis=1,keepdims=True)/6
  y_center_left = torch.sum(y[:,0:6],axis=1,keepdims=True)/6
  y_center_right = torch.sum(y[:,6:12],axis=1,keepdims=True)/6
  dist = torch.sqrt((x_center_left-x_center_right)**2 + (y_center_left-y_center_right)**2)

  Err = ((x-x_label)**2 + (y-y_label)**2)/dist
  return torch.sum(Err)/x.shape[0]/12

# %%
NME_loss_select = NME_loss = coord_loss = coord_loss_select = 0
Tune_HGNet.eval()

for i, (img,coord,hm) in enumerate(test_dataloder):
  img = img.float().to(device)
  img.requires_grad = True
  coord = coord.float().to(device)
  hm = hm.float().to(device)
  B = img.shape[0]
  
  outputs = Tune_HGNet.forward(img)
  pred_heatmaps = torch.matmul(phi(outputs),leaf_q.reshape(num_leaf_nodes,-1)) #(15,12*256*256)
  pred_heatmaps_select = torch.matmul(phi(outputs,mode='test'),leaf_q.reshape(num_leaf_nodes,-1)) #(15,12*256*256)
  pred_coord0 = find_coord(pred_heatmaps)
  pred_coords = find_coord(pred_heatmaps_select) #(15,12*2)

  #heatmap_loss += criterion(pred_heatmaps, hm[:,36:48,:,:].reshape(B,-1))
  coord_loss += torch.sum(torch.abs(pred_coord0-coord[:,36:48,:].reshape(B,-1)))/B
  coord_loss_select += torch.sum(torch.abs(pred_coords-coord[:,36:48,:].reshape(B,-1)))/B
  NME_loss += NME_eye(pred_coord0,coord[:,36:48,:].reshape(B,-1))
  NME_loss_select += NME_eye(pred_coords,coord[:,36:48,:].reshape(B,-1))

print("Coord L1 loss %.4f, after selection: %.4f" %(coord_loss/11, coord_loss_select/11))
print("Coord NME loss %.4f, after selection: %.4f" %(NME_loss/11, NME_loss_select/11))

# %%
# Coords

for ith in range(10):
  x = pred_coord0[ith,::2].detach().cpu()
  y = pred_coord0[ith,1::2].detach().cpu()
  plt.scatter(x,256-y,label="Prediction")

  x2 = coord[ith,36:48,0].detach().cpu()
  y2 = coord[ith,36:48,1].detach().cpu()
  plt.scatter(x2,256-y2,label="GT")

  plt.legend(loc='lower left')
  plt.xlim(0,256)
  plt.ylim(0,256)
  plt.title(str(ith)+"th prediction - Full")
  plt.show()

# %%
# Coords

for ith in range(10):
  x = pred_coords[ith,::2].detach().cpu()
  y = pred_coords[ith,1::2].detach().cpu()
  plt.scatter(x,256-y,label="Prediction")

  x2 = coord[ith,36:48,0].detach().cpu()
  y2 = coord[ith,36:48,1].detach().cpu()
  plt.scatter(x2,256-y2,label="GT")

  plt.legend(loc='lower left')
  plt.xlim(0,256)
  plt.ylim(0,256)
  plt.title(str(ith)+"th prediction - Selected")
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a0c8a75a530f> in <module>()
#       2
#       3 for ith in range(10):
# ----> 4   x = pred_coords[ith,::2].detach().cpu()
#       5   y = pred_coords[ith,1::2].detach().cpu()
#       6   plt.scatter(x,256-y,label="Prediction")
#
# NameError: name 'pred_coords' is not defined

# %%
plot_heatmaps = pred_heatmaps.reshape(B,12,256,256).detach().cpu()
plot_heatmaps_all = torch.sum(plot_heatmaps,axis=1)
for ith in range(10):
  plt.imshow(plot_heatmaps_all[ith,:,:])
  plt.title(str(ith)+"th prediction heatmap")
  plt.show()

# %%
for nleaf in range(48):
  plt.imshow(leaf_q.reshape(num_leaf_nodes,12,256,256)[nleaf,0,:,:].detach().cpu())
  plt.title(str(ith)+"th leafnode, first point, first img")
  plt.show()

# %%
image = torch.sum(hm, axis=1).detach().cpu()
plt.imshow(image[ith,:,:])

# %%
plt.imshow(img[ith,:,:,:].detach().cpu().permute(1,2,0).int())
