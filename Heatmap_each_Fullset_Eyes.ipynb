# %% [markdown]
# <a href="https://colab.research.google.com/github/Pengchengzhi/Face-Alignment-DRF/blob/main/Heatmap_each_Fullset_Eyes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This program generates one heatmap for each landmark, while `Heatmap_all.ipynb` generates one heatmap for all landmarks.

# %% [markdown]
# * 不要用 Gaussian 做 Label，匹配 Loss Function 的形状，保证理论上误差为0.

# %% [markdown]
# # 1. Initialize

# %%
# function ConnectButton(){
#   console.log("Connect pushed"); 
#   document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click() 
# }
# setInterval(ConnectButton,60000);


# clearInterval(37042)

# %%
from google.colab import drive
drive.mount("/content/drive")

import os
path="/content/drive/My Drive/Face Alignment DRF"
os.chdir(path)
os.listdir(path)
# Out:
# Mounted at /content/drive
# ['Procruses Analysis.ipynb',
#  'PCA.ipynb',
#  '__pycache__',
#  'utils',
#  'datasets',
#  'Gaussian.ipynb',
#  'Heatmap_all.ipynb',
#  'trained_models',
#  'DataPreprocessing.ipynb',
#  'checkpoints',
#  'Heatmap_each.ipynb',
#  'Update_leaf.ipynb']

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import os
import cv2
import json
import pandas as pd
from PIL import Image
import torchvision.models as models
import pdb
from torch.nn import Upsample
from torch.autograd import Variable
import torch.optim as optim
import time

import warnings
warnings.filterwarnings('ignore')

# %%
from utils.hourglass import *
from utils.dataloader import *

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
dim_tree = 5 # how deep the regression tree is 
num_tree = 3 # number of regression trees
variance_gaussian = 3

num_fc = int(num_tree*(2**(dim_tree-1)-1))
num_leaf_nodes = int(num_tree*2**(dim_tree-1))

# %% [markdown]
# # 2. Data Loader

# %%
helen_trainset = Helen_set(dataset_type="train",var=variance_gaussian)
# Out:
# Loading [1/2000] pictures......
# Loading [400/2000] pictures......
# Loading [800/2000] pictures......
# Loading [1200/2000] pictures......
# Loading [1600/2000] pictures......
# Loading [2000/2000] pictures......

# %%
helen_testset = Helen_set(dataset_type="test",var=variance_gaussian)
# Out:
# Loading [1/330] pictures......
# Loading [200/330] pictures......

# %%
train_dataloder = DataLoader(helen_trainset, batch_size=25)
test_dataloder = DataLoader(helen_testset, batch_size=30)

# %% [markdown]
# # 3. Pre Train

# %%
# helen_sampleset = Helen_set(dataset_type="sample")
# sample_dataloder = DataLoader(helen_sampleset, batch_size=20)

# %%
# critical = torch.nn.MSELoss()

# nIters = 200
# HGNet = HGNet().to(device)
# optimizer = optim.SGD(HGNet.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-4)

# %%
# loss_hist = torch.zeros(nIters)
# loss_epoch = torch.zeros(10)

# for iter in range(nIters):
#   for i, (x,_,y) in enumerate(sample_dataloder):
#     x = Variable(x,requires_grad=True).float().to(device)
#     y = Variable(y).float().to(device)
#     y_pred = HGNet.forward(x)
#     loss = critical(y_pred, y)
#     loss_epoch[i] = loss.item()

#     if i == 9:
#       loss_avg = torch.sum(loss_epoch)/10
#       loss_hist[iter] = loss_avg
#       if (iter+1)%10 == 0 or iter == 0:
#         print('Iter [%d/%d] loss %.4f' %(iter+1, nIters, loss_avg))
        
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()

# plt.plot(torch.arange(nIters),loss_hist.detach().numpy())
# plt.title("Training Loss")

# %%
# torch.save(HGNet.state_dict(), "/content/drive/My Drive/Face Alignment DRF/trained_models/Original_HGNet.pt")

# %% [markdown]
# # 4. Tune Training

# %% [markdown]
# ## 4.1 Functions

# %% [markdown]
# ![PHI.png](data:image/png;base64,...)

# %%
def leaf_direction(N):
  point = torch.zeros(2**N,N).to(device)

  def get01(number, len):
    result = torch.zeros(len).to(device)
    ind = len
    while ind >0:
      if 2**(ind-1)<=number:
        result[len-ind] = 1
        number -= 2**(ind-1)
      ind -= 1
    return result
  
  for i in range(2**N):
    point[i,:] = get01(i,N)

  return point.int()

# %%
def split_tree(up,here,which=0,mode='Second'):
  if mode=='initial':
    if which == 0:
      return here
    else: return (1-here)
  else:
    if which == 0:
      return up*here
    else: return up*(1-here)

# %%
def split_base(N):
  # returns index that split based on which cnn_fc col
  res = torch.zeros(2**N*N).to(device)
  lenth = 2**(N-1)
  num = 1
  left = 0
  repeat = 1
  max_repeat = 1
  while lenth>0 and repeat<2**N:
    res[left:left+lenth*2] = num
    left += lenth*2
    num += 1
    repeat -= 1
    if repeat == 0:
      lenth = int(lenth/2)
      repeat = max_repeat*2
      max_repeat = repeat
  return ((res.reshape(N,2**N)-1).T).int()

# %%
def phi(cnn_fc,mode='train'):
  N = cnn_fc.shape[0]
  out = torch.zeros(N,num_leaf_nodes).to(device)
  sigm = torch.zeros(cnn_fc.shape).to(device)

  if mode == 'test':
    sigm[cnn_fc>0] = 1
  else:
    sigm = torch.sigmoid(cnn_fc)

  direction = leaf_direction(dim_tree-1)
  tree_ind = split_base(dim_tree-1)
  X, Y = tree_ind.shape

  for ind_tree in range(num_tree):
    for x in range(X):
      for y in range(Y):
        here = sigm[:,ind_tree*(X-1)+tree_ind[x,y]]
        if y == 0:
          up = split_tree(torch.rand(3).to(device),here,which=direction[x,y],mode='initial')
        else:
          up = split_tree(up,here,which=direction[x,y])
        #print('y',y,'up',up)

      out[:,ind_tree*X+x] = up
    
  return out

# %%
def find_coord(prob_map):
  # prob_map(200,68*256*256)

  N = prob_map.shape[0]
  P = 12
  coord = torch.zeros(N,P*2).to(device)
  heatmap = prob_map.reshape(N,P,256,256).float()
  for n in range(N):
    for p in range(P):
      c1, c2 = torch.where(heatmap[n,p,:,:]==torch.max(heatmap[n,p,:,:]))
      coord[n,2*p], coord[n,2*p+1] = c1[0], c2[0]

  return coord

# %%
def get_mask(cnn_heatmaps,threshold=0.3):
  mask = torch.zeros(cnn_heatmaps.shape).to(device)
  B, P = cnn_heatmaps.shape[0:2]
  for b in range(B):
    for p in range(P):
      hm = cnn_heatmaps[b,p,:,:]
      mask[b,p,:,:][hm>torch.max(hm)*threshold]=1
  return mask

# %%
def update_iter(q, p, l):
  # q: leaf node
  # p: cnn probability
  # l: label

  gamma = torch.unsqueeze(p,2)*torch.unsqueeze(q,0) # (Ntrain,Nleaf,Nlabel)
  gamma = gamma/(torch.sum(gamma,axis=1,keepdims=True)+1e-8)
  score = torch.zeros(gamma.shape).to(q.device)
  for ll in range(q.shape[0]):
    score[:,ll,:] = l*gamma[:,ll,:]
  score = torch.sum(score,axis=0)+1e-8 # (3,2)

  return score/torch.sum(score,axis=1,keepdims=True)

# %%
def loss_ce(B, q, p, l):
  pred = torch.matmul(p,q.reshape(num_leaf_nodes,-1)).reshape(B*12,-1)
  pred = pred/torch.sum(pred,axis=1,keepdims=True)
  l = l.reshape(B*12,-1)
  l = l/torch.sum(l,axis=1,keepdims=True)

  return -criterion_KL(l,pred)

def loss_l1(q, p, l):
  return torch.sum(torch.abs(torch.matmul(p,q)-l))/l.shape[0]

def loss_alogb(B, q, p, l):
  pred = torch.matmul(p,q.reshape(num_leaf_nodes,-1)).reshape(B*12,-1)
  pred = pred/torch.sum(pred,axis=1,keepdims=True)
  l = l.reshape(B*12,-1)
  l = l/torch.sum(l,axis=1,keepdims=True)

  return -torch.sum(l*torch.log(pred))/B

# %%
# def mask_and_norm(target, mask):
#   # target (B,12,256,256)
#   # mask (B,12,256,256)
#   B,P = target.shape[0:2]

#   res = (target*mask).reshape(B,P,-1)
#   res = res/torch.sum(res,axis=2,keepdims=True)
#   return res.reshape(B,-1)

# %% [markdown]
# ## 4.2 Sample Set

# %%
# helen_sampleset = Helen_set(dataset_type="sample",var=variance_gaussian)
# sample_dataloder = DataLoader(helen_sampleset, batch_size=20) 
# helen_sampletest = Helen_set(dataset_type="sample_test",var=variance_gaussian)
# sample_test_dataloder = DataLoader(helen_sampletest, batch_size=10)
# Out:
# Loading [1/200] pictures......
# Loading [100/200] pictures......
# Loading [200/200] pictures......
# Loading [1/30] pictures......

# %% [markdown]
# ## 4.3 Network

# %%
Tune_HGNet = HGNet(tune=True).to(device)
Tune_HGNet.load_state_dict(torch.load("/content/drive/My Drive/Face Alignment DRF/trained_models/Original_HGNet.pt"))
# Out:
# <All keys matched successfully>

# %%
Tune_HGNet._HGNet__lin = nn.Sequential(nn.Conv2d(128,64,1),
                    nn.BatchNorm2d(64),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(4,4),  #(64,64,64)
                    nn.Conv2d(64,16,1),
                    nn.BatchNorm2d(16),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2),  #(16,32,32)
                    nn.Conv2d(16,4,1),
                    nn.BatchNorm2d(4),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2)).to(device)  #(4,16,16)

Tune_HGNet._HGNet__tune = nn.Sequential(nn.Linear(4*16*16,num_fc)).to(device)

# %% [markdown]
# ## 4.4 Training

# %%
#######################
# Initialization
Total_train = 10

# CNN initilization
nIters = 200
learning_rate = 0.01

criterion_MSE = torch.nn.MSELoss()
criterion_KL = torch.nn.KLDivLoss()
optimizer = optim.SGD(Tune_HGNet.parameters(), lr=learning_rate, momentum=0.9, weight_decay=1e-4)

# Regression Tree parameters
rf_Iters = 60

# %% [markdown]
# ### Training using L2 Loss

# %%
# Using L2 Loss

for round in range(Total_train):
  print("###########################################################")
  if torch.cuda.is_available():
    print("Round %d, Using GPU" %(round+1))
  else:
    print("Round ", round+1)
  
  #####################################
  ### Train Hourglass
  ### eyes: [36:48]
  #####################################
  if round == 0:
    leaf_q = torch.ones(num_leaf_nodes,12*256*256).to(device)/(256*256)
    cnn_Iters = 30
  else:
    cnn_Iters = nIters

  for iter in range(cnn_Iters):
    loss_epoch = 0
    for i, (x,_,y) in enumerate(sample_dataloder):
      x = x.float().to(device)
      x.requires_grad = True
      y = y.float().to(device)
      B = x.shape[0]

      outputs = Tune_HGNet.forward(x)
      cnn_prob = phi(outputs)
      cnn_heatmaps = torch.matmul(cnn_prob,leaf_q).reshape(B,12,256,256)
      # get mask for computing cnn loss
      cnn_mask = get_mask(cnn_heatmaps,threshold=0.5)
      loss = criterion_MSE(cnn_heatmaps*cnn_mask, y[:,36:48,:,:]*cnn_mask)

      loss_epoch += loss.item()
      if (iter+1)%20 == 0 or iter == 0:
        if i == 9:
          print('     CNN training, Iter [%d/%d], loss_L2: %.8f' %(iter+1, cnn_Iters, loss_epoch*224*224*1e-1))

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()


  #####################################
  ### Train Regression Trees using pinv
  #####################################
  with torch.no_grad():
    leaf_q_new = torch.zeros(num_leaf_nodes,12*256*256).to(device)
    loss0 = 0

    for i, (x,coord,y) in enumerate(sample_dataloder):
      x = x.float().to(device)
      y = y.float().to(device)
      coord = coord.float().to(device)
      B = x.shape[0]
      y_expand = y[:,36:48,:,:].reshape(B,-1) #(200,12*256*256)

      outputs = Tune_HGNet.forward(x)
      cnn_prob = phi(outputs)

      pred_coord0 = find_coord(torch.matmul(cnn_prob,leaf_q))
      loss0 += torch.sum(torch.abs(pred_coord0-coord[:,36:48,:].reshape(B,-1)))

      leaf_q_new += torch.matmul(torch.linalg.pinv(cnn_prob), y_expand) #(8,12*256*256)

    leaf_q = leaf_q_new/10  # average among each bach
    leaf_q = torch.abs(leaf_q.reshape(num_leaf_nodes,12,-1)) #(B,12,256*256)
    leaf_q = leaf_q/torch.sum(leaf_q, axis=2, keepdims=True)
    for nleaf in range(num_leaf_nodes):
      for npoints in range(12):
        leaf_q[nleaf,npoints,:][leaf_q[nleaf,npoints,:] <= torch.max(leaf_q[nleaf,npoints,:])*0.2] = 0
    leaf_q = leaf_q/torch.sum(leaf_q, axis=2, keepdims=True)
    leaf_q = leaf_q.reshape(num_leaf_nodes,-1)

    print("     RF training, coordinate loss: %.4f" %(loss0/10))
# Out:
# ###########################################################
# Round 1, Using GPU
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-5080c6c81955> in <module>()
#      20   for iter in range(cnn_Iters):
#      21     loss_epoch = 0
# ---> 22     for i, (x,_,y) in enumerate(sample_dataloder):
#      23       x = x.float().to(device)
#      24       x.requires_grad = True
#
# NameError: name 'sample_dataloder' is not defined

# %% [markdown]
# ### Training using Log likelihood

# %%
# update using log likelihood

time_initial = time.time()
for round in range(Total_train):
  time_start = time.time()
  print("############################################################################")
  if torch.cuda.is_available():
    print("Round [%d/%d], Using GPU" %(round+1, Total_train))
  else:
    print("Round [%d/%d]" %(round+1, Total_train))

  
  ######################################################
  ### Train Hourglass using gradient decent
  ### eyes: [36:48]
  ######################################################
  if round == 0:
    leaf_q = torch.ones(num_leaf_nodes,12,256*256).to(device)/(256*256)
    cnn_Iters = 30
  else:
    cnn_Iters = nIters

  for iter in range(cnn_Iters):
    loss_epoch = 0
    for i, (x,_,y) in enumerate(train_dataloder):
      x = x.float().to(device)
      x.requires_grad = True
      y = y.float().to(device)
      B = x.shape[0]

      outputs = Tune_HGNet.forward(x)*(round*0.2+1)
      cnn_prob = phi(outputs)

      cnn_heatmaps = torch.matmul(cnn_prob,leaf_q.reshape(num_leaf_nodes,-1)).reshape(B*12,-1)
      cnn_heatmaps = cnn_heatmaps/torch.sum(cnn_heatmaps,axis=1,keepdims=True)
      label_heatmaps = y[:,36:48,:,:].reshape(B*12,-1)
      label_heatmaps = label_heatmaps/torch.sum(label_heatmaps,axis=1,keepdims=True)
      #loss = -criterion_KL(cnn_heatmaps,label_heatmaps)
      loss = -torch.sum(label_heatmaps*torch.log(cnn_heatmaps+1e-8))/B

      loss_epoch += loss.item()
      if (iter+1)%5 == 0 or iter == 0:
        if i == 79:
          loss_epoch = loss_epoch/80
          print('     CNN training, Iter [%d/%d], loss_CE: %.4f' %(iter+1, cnn_Iters, loss_epoch))

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

  # calculate time for CNN training
  time_cnn = time.time()
  print("     -----> CNN training time: ## %.2f mins ## " %((time_cnn-time_start)/60))

  # plot the face after CNN training
  # Does not select
  cnn_heatmaps = torch.matmul(cnn_prob,leaf_q.reshape(num_leaf_nodes,-1)).reshape(B,12,-1)
  first_face = torch.sum(cnn_heatmaps[0,:,:],axis=0)
  first_face = first_face/torch.sum(first_face)
  plt.imshow(first_face.reshape(256,256).detach().cpu())
  plt.title("Anneal: Round"+str(round+1)+"_CNN Full")
  plt.savefig(os.path.join("checkpoints/Anneal_Full_Train/var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+"_CNN_Full.png"))
  plt.show()

  # Selcet
  cnn_prob_test = phi(outputs, mode='test')
  cnn_heatmaps = torch.matmul(cnn_prob_test,leaf_q.reshape(num_leaf_nodes,-1)).reshape(B,12,-1)
  first_face = torch.sum(cnn_heatmaps[0,:,:],axis=0)
  first_face = first_face/torch.sum(first_face)
  plt.imshow(first_face.reshape(256,256).detach().cpu())
  plt.title("Anneal: Round"+str(round+1)+"_CNN Select")
  plt.savefig(os.path.join("checkpoints/Anneal_Full_Train/var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+"_CNN_Select.png"))
  plt.show()

  ######################################################
  ### Train Regression Trees using variational bounding
  ######################################################
  with torch.no_grad():
    loss0,loss_select = 0,0
    leaf_q = leaf_q.reshape(num_leaf_nodes,12,256*256)
    new_leaf_q = torch.zeros(leaf_q.shape).to(device)

    for i, (x,coord,y) in enumerate(train_dataloder):
      next_leaf_q = leaf_q.clone()
      x = x.float().to(device)
      y = y.float().to(device)
      coord = coord.float().to(device)
      B = x.shape[0]
      y_expand = y[:,36:48,:,:].reshape(B,12,-1) #(200,12*256*256)

      outputs = Tune_HGNet.forward(x)*(round*0.2+1)
      cnn_prob = phi(outputs)
      cnn_prob_select = phi(outputs, mode='test')
  
      for rf_iter in range(rf_Iters):
        for points_id in range(12):
          next_leaf_q[:,points_id,:] = update_iter(next_leaf_q[:,points_id,:], cnn_prob, y_expand[:,points_id,:])
        if ((i+1)%15 == 0 or i == 0) and ((rf_iter+1)%10 == 0 or rf_iter == 0):
          rf_loss_CE = loss_alogb(B, next_leaf_q, cnn_prob, y_expand)
          print("     RF training, Batch %d, rf_iter [%d/%d], loss_CE: %.4f" %(i+1, rf_iter+1, rf_Iters, rf_loss_CE))

      # Calculate loss
      pred_coord0 = find_coord(torch.matmul(cnn_prob,next_leaf_q.reshape(num_leaf_nodes,-1)))
      loss0 += torch.sum(torch.abs(pred_coord0-coord[:,36:48,:].reshape(B,-1)))/B
      pred_coord_select = find_coord(torch.matmul(cnn_prob_select,next_leaf_q.reshape(num_leaf_nodes,-1)))
      loss_select += torch.sum(torch.abs(pred_coord_select-coord[:,36:48,:].reshape(B,-1)))/B

      # update leaf node
      new_leaf_q += next_leaf_q
    leaf_q = new_leaf_q/torch.sum(new_leaf_q, axis=2, keepdims=True)
    


  # plot the face after rf training
  # Does not select
  rf_heatmaps = torch.matmul(cnn_prob,leaf_q.reshape(num_leaf_nodes,-1)).reshape(B,12,-1)
  first_face = torch.sum(rf_heatmaps[0,:,:],axis=0)
  first_face = first_face/torch.sum(first_face)
  plt.imshow(first_face.reshape(256,256).detach().cpu())
  plt.title("Anneal: Round"+str(round+1)+"_RF Full")
  plt.savefig(os.path.join("checkpoints/Anneal_Full_Train/var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+"_RF_Full.png"))
  plt.show()

  # Select
  cnn_prob_test = phi(outputs, mode='test')
  rf_heatmaps = torch.matmul(cnn_prob_test,leaf_q.reshape(num_leaf_nodes,-1)).reshape(B,12,-1)
  first_face = torch.sum(rf_heatmaps[0,:,:],axis=0)
  first_face = first_face/torch.sum(first_face)
  plt.imshow(first_face.reshape(256,256).detach().cpu())
  plt.title("Anneal: Round"+str(round+1)+"_RF Select")
  plt.savefig(os.path.join("checkpoints/Anneal_Full_Train/var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+"_RF_Select.png"))
  plt.show()

  print("     RF training, coordinate loss: %.2f, after selcetion: %.2f" %(loss0/80, loss_select/80))

  # save parameters for this round
  torch.save(Tune_HGNet.state_dict(), os.path.join("checkpoints/Anneal_Full_Train/Tune_HGNet_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+'.pt'))
  torch.save(leaf_q, os.path.join("checkpoints/Anneal_Full_Train/leaf_q_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_Round"+str(round+1)+'.pt'))

  # calculate time for rf training
  time_rf = time.time()
  print("     -----> RF training time: ## %.2f mins ## " %((time_rf-time_cnn)/60))
  print("     -----> Training time for this round: ## %.2f mins ## " %((time_rf-time_start)/60))

# Finish Training
torch.save(Tune_HGNet.state_dict(), os.path.join("checkpoints/Anneal_Full_Train/Tune_HGNet_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_final.pt"))
torch.save(leaf_q, os.path.join("checkpoints/Anneal_Full_Train/leaf_q_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_final.pt"))

# calculate total training time
time_end = time.time()
print("-----> Total training time: ## %.2f hrs ## " %((time_end-time_initial)/3600))
# Out:
# ############################################################################
# Round [1/10], Using GPU
#      CNN training, Iter [1/30], loss_CE: 133.0764
#      CNN training, Iter [5/30], loss_CE: 133.0764
#      CNN training, Iter [10/30], loss_CE: 133.0764
#      CNN training, Iter [15/30], loss_CE: 133.0764
#      CNN training, Iter [20/30], loss_CE: 133.0764
#      CNN training, Iter [25/30], loss_CE: 133.0764
#      CNN training, Iter [30/30], loss_CE: 133.0764
#      -----> CNN training time: ## 23.54 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_CE: 89.7612
#      RF training, Batch 1, rf_iter [10/60], loss_CE: 87.2548
#      RF training, Batch 1, rf_iter [20/60], loss_CE: 86.7027
#      RF training, Batch 1, rf_iter [30/60], loss_CE: 86.5325
#      RF training, Batch 1, rf_iter [40/60], loss_CE: 86.4570
#      RF training, Batch 1, rf_iter [50/60], loss_CE: 86.4166
#      RF training, Batch 1, rf_iter [60/60], loss_CE: 86.3925
#      RF training, Batch 15, rf_iter [1/60], loss_CE: 89.3563
#      RF training, Batch 15, rf_iter [10/60], loss_CE: 87.0534
#      RF training, Batch 15, rf_iter [20/60], loss_CE: 86.4515
#      RF training, Batch 15, rf_iter [30/60], loss_CE: 86.2600
#      RF training, Batch 15, rf_iter [40/60], loss_CE: 86.1791
#      RF training, Batch 15, rf_iter [50/60], loss_CE: 86.1379
#      RF training, Batch 15, rf_iter [60/60], loss_CE: 86.1142
#      RF training, Batch 30, rf_iter [1/60], loss_CE: 89.8671
#      RF training, Batch 30, rf_iter [10/60], loss_CE: 87.4084
#      RF training, Batch 30, rf_iter [20/60], loss_CE: 86.7997
#      RF training, Batch 30, rf_iter [30/60], loss_CE: 86.6161
#      RF training, Batch 30, rf_iter [40/60], loss_CE: 86.5404
#      RF training, Batch 30, rf_iter [50/60], loss_CE: 86.5020
#      RF training, Batch 30, rf_iter [60/60], loss_CE: 86.4797
#      RF training, Batch 45, rf_iter [1/60], loss_CE: 88.4810
#      RF training, Batch 45, rf_iter [10/60], loss_CE: 86.3017
#      RF training, Batch 45, rf_iter [20/60], loss_CE: 85.7258
#      RF training, Batch 45, rf_iter [30/60], loss_CE: 85.5412
#      RF training, Batch 45, rf_iter [40/60], loss_CE: 85.4606
#      RF training, Batch 45, rf_iter [50/60], loss_CE: 85.4183
#      RF training, Batch 45, rf_iter [60/60], loss_CE: 85.3934
#      RF training, Batch 60, rf_iter [1/60], loss_CE: 90.2339
#      RF training, Batch 60, rf_iter [10/60], loss_CE: 87.9421
#      RF training, Batch 60, rf_iter [20/60], loss_CE: 87.3736
#      RF training, Batch 60, rf_iter [30/60], loss_CE: 87.1820
#      RF training, Batch 60, rf_iter [40/60], loss_CE: 87.0970
#      RF training, Batch 60, rf_iter [50/60], loss_CE: 87.0524
#      RF training, Batch 60, rf_iter [60/60], loss_CE: 87.0261
#      RF training, Batch 75, rf_iter [1/60], loss_CE: 91.8577
#      RF training, Batch 75, rf_iter [10/60], loss_CE: 88.7752
#      RF training, Batch 75, rf_iter [20/60], loss_CE: 88.1545
#      RF training, Batch 75, rf_iter [30/60], loss_CE: 87.9806
#      RF training, Batch 75, rf_iter [40/60], loss_CE: 87.9121
#      RF training, Batch 75, rf_iter [50/60], loss_CE: 87.8782
#      RF training, Batch 75, rf_iter [60/60], loss_CE: 87.8588
#      RF training, coordinate loss: 299.61, after selcetion: 296.95
#      -----> RF training time: ## 104.34 mins ##
#      -----> Training time for this round: ## 127.88 mins ##
# ############################################################################
# Round [2/10], Using GPU
#      CNN training, Iter [1/200], loss_CE: 98.3641
#      CNN training, Iter [5/200], loss_CE: 95.9510
#      CNN training, Iter [10/200], loss_CE: 95.3165
#      CNN training, Iter [15/200], loss_CE: 95.1172
#      CNN training, Iter [20/200], loss_CE: 94.9663
#      CNN training, Iter [25/200], loss_CE: 94.7472
#      CNN training, Iter [30/200], loss_CE: 94.6354
#      CNN training, Iter [35/200], loss_CE: 94.5951
#      CNN training, Iter [40/200], loss_CE: 94.5730
#      CNN training, Iter [45/200], loss_CE: 94.5130
#      CNN training, Iter [50/200], loss_CE: 94.5026
#      CNN training, Iter [55/200], loss_CE: 94.4587
#      CNN training, Iter [60/200], loss_CE: 94.4443
#      CNN training, Iter [65/200], loss_CE: 94.4333
#      CNN training, Iter [70/200], loss_CE: 94.4277
#      CNN training, Iter [75/200], loss_CE: 94.4199
#      CNN training, Iter [80/200], loss_CE: 94.4188
#      CNN training, Iter [85/200], loss_CE: 94.4115
#      CNN training, Iter [90/200], loss_CE: 94.4097
#      CNN training, Iter [95/200], loss_CE: 94.4052
#      CNN training, Iter [100/200], loss_CE: 94.4011
#      CNN training, Iter [105/200], loss_CE: 94.3990
#      CNN training, Iter [110/200], loss_CE: 94.3960
#      CNN training, Iter [115/200], loss_CE: 94.3952
#      CNN training, Iter [120/200], loss_CE: 94.3915
#      CNN training, Iter [125/200], loss_CE: 94.3888
#      CNN training, Iter [130/200], loss_CE: 94.3886
#      CNN training, Iter [135/200], loss_CE: 94.3853
#      CNN training, Iter [140/200], loss_CE: 94.3880
#      CNN training, Iter [145/200], loss_CE: 94.3822
#      CNN training, Iter [150/200], loss_CE: 94.3807
#      CNN training, Iter [155/200], loss_CE: 94.3785
#      CNN training, Iter [160/200], loss_CE: 94.3772
#      CNN training, Iter [165/200], loss_CE: 94.3777
#      CNN training, Iter [170/200], loss_CE: 94.3702
#      CNN training, Iter [175/200], loss_CE: 94.3673
#      CNN training, Iter [180/200], loss_CE: 94.3671
#      CNN training, Iter [185/200], loss_CE: 94.3615
#      CNN training, Iter [190/200], loss_CE: 94.3584
#      CNN training, Iter [195/200], loss_CE: 94.3590
#      CNN training, Iter [200/200], loss_CE: 94.3552
#      -----> CNN training time: ## 152.65 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_CE: 69.4560
#      RF training, Batch 1, rf_iter [10/60], loss_CE: 68.0559
#      RF training, Batch 1, rf_iter [20/60], loss_CE: 67.9538
#      RF training, Batch 1, rf_iter [30/60], loss_CE: 67.9295
#      RF training, Batch 1, rf_iter [40/60], loss_CE: 67.9199
#      RF training, Batch 1, rf_iter [50/60], loss_CE: 67.9153
#      RF training, Batch 1, rf_iter [60/60], loss_CE: 67.9128
#      RF training, Batch 15, rf_iter [1/60], loss_CE: 69.8746
#      RF training, Batch 15, rf_iter [10/60], loss_CE: 68.2949
#      RF training, Batch 15, rf_iter [20/60], loss_CE: 68.1811
#      RF training, Batch 15, rf_iter [30/60], loss_CE: 68.1554
#      RF training, Batch 15, rf_iter [40/60], loss_CE: 68.1453
#      RF training, Batch 15, rf_iter [50/60], loss_CE: 68.1404
#      RF training, Batch 15, rf_iter [60/60], loss_CE: 68.1377
#      RF training, Batch 30, rf_iter [1/60], loss_CE: 72.3965
#      RF training, Batch 30, rf_iter [10/60], loss_CE: 70.5439
#      RF training, Batch 30, rf_iter [20/60], loss_CE: 70.4337
#      RF training, Batch 30, rf_iter [30/60], loss_CE: 70.4132
#      RF training, Batch 30, rf_iter [40/60], loss_CE: 70.4061
#      RF training, Batch 30, rf_iter [50/60], loss_CE: 70.4027
#      RF training, Batch 30, rf_iter [60/60], loss_CE: 70.4008
#      RF training, Batch 45, rf_iter [1/60], loss_CE: 69.5524
#      RF training, Batch 45, rf_iter [10/60], loss_CE: 67.8046
#      RF training, Batch 45, rf_iter [20/60], loss_CE: 67.7348
#      RF training, Batch 45, rf_iter [30/60], loss_CE: 67.7207
#      RF training, Batch 45, rf_iter [40/60], loss_CE: 67.7158
#      RF training, Batch 45, rf_iter [50/60], loss_CE: 67.7134
#      RF training, Batch 45, rf_iter [60/60], loss_CE: 67.7121
#      RF training, Batch 60, rf_iter [1/60], loss_CE: 71.2703
#      RF training, Batch 60, rf_iter [10/60], loss_CE: 69.4637
#      RF training, Batch 60, rf_iter [20/60], loss_CE: 69.3643
#      RF training, Batch 60, rf_iter [30/60], loss_CE: 69.3444
#      RF training, Batch 60, rf_iter [40/60], loss_CE: 69.3372
#      RF training, Batch 60, rf_iter [50/60], loss_CE: 69.3339
#      RF training, Batch 60, rf_iter [60/60], loss_CE: 69.3321
#      RF training, Batch 75, rf_iter [1/60], loss_CE: 71.5127
#      RF training, Batch 75, rf_iter [10/60], loss_CE: 69.5812
#      RF training, Batch 75, rf_iter [20/60], loss_CE: 69.4451
#      RF training, Batch 75, rf_iter [30/60], loss_CE: 69.4075
#      RF training, Batch 75, rf_iter [40/60], loss_CE: 69.3933
#      RF training, Batch 75, rf_iter [50/60], loss_CE: 69.3864
#      RF training, Batch 75, rf_iter [60/60], loss_CE: 69.3822
#      RF training, coordinate loss: 67.54, after selcetion: 82.25
#      -----> RF training time: ## 103.55 mins ##
#      -----> Training time for this round: ## 256.20 mins ##
# ############################################################################
# Round [3/10], Using GPU
#      CNN training, Iter [1/200], loss_CE: 87.7802
#      CNN training, Iter [5/200], loss_CE: 85.1337
#      CNN training, Iter [10/200], loss_CE: 84.5114
#      CNN training, Iter [15/200], loss_CE: 84.2173
#      CNN training, Iter [20/200], loss_CE: 84.1242
#      CNN training, Iter [25/200], loss_CE: 84.0757
#      CNN training, Iter [30/200], loss_CE: 84.0576
#      CNN training, Iter [35/200], loss_CE: 84.0316
#      CNN training, Iter [40/200], loss_CE: 84.0204
#      CNN training, Iter [45/200], loss_CE: 84.0137
#      CNN training, Iter [50/200], loss_CE: 83.9929
#      CNN training, Iter [55/200], loss_CE: 83.9793
#      CNN training, Iter [60/200], loss_CE: 83.9742
#      CNN training, Iter [65/200], loss_CE: 83.9630
#      CNN training, Iter [70/200], loss_CE: 83.9535
#      CNN training, Iter [75/200], loss_CE: 83.9454
#      CNN training, Iter [80/200], loss_CE: 83.9404
#      CNN training, Iter [85/200], loss_CE: 83.9311
#      CNN training, Iter [90/200], loss_CE: 83.9243
#      CNN training, Iter [95/200], loss_CE: 83.9248
#      CNN training, Iter [100/200], loss_CE: 83.9196
#      CNN training, Iter [105/200], loss_CE: 83.9186
#      CNN training, Iter [110/200], loss_CE: 83.9187
#      CNN training, Iter [115/200], loss_CE: 83.9111
#      CNN training, Iter [120/200], loss_CE: 83.9039
#      CNN training, Iter [125/200], loss_CE: 83.9045
#      CNN training, Iter [130/200], loss_CE: 83.9038
#      CNN training, Iter [135/200], loss_CE: 83.8962
#      CNN training, Iter [140/200], loss_CE: 83.8936
#      CNN training, Iter [145/200], loss_CE: 83.8923
#      CNN training, Iter [150/200], loss_CE: 83.8832
#      CNN training, Iter [155/200], loss_CE: 83.8781
#      CNN training, Iter [160/200], loss_CE: 83.8732
#      CNN training, Iter [165/200], loss_CE: 83.8707
#      CNN training, Iter [170/200], loss_CE: 83.8639
#      CNN training, Iter [175/200], loss_CE: 83.8625
#      CNN training, Iter [180/200], loss_CE: 83.8578
#      CNN training, Iter [185/200], loss_CE: 83.8559
#      CNN training, Iter [190/200], loss_CE: 83.8527
#      CNN training, Iter [195/200], loss_CE: 83.8523
#      CNN training, Iter [200/200], loss_CE: 83.8488
#      -----> CNN training time: ## 151.79 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_CE: 67.8588
#      RF training, Batch 1, rf_iter [10/60], loss_CE: 66.7392
#      RF training, Batch 1, rf_iter [20/60], loss_CE: 66.6796
#      RF training, Batch 1, rf_iter [30/60], loss_CE: 66.6632
#      RF training, Batch 1, rf_iter [40/60], loss_CE: 66.6554
#      RF training, Batch 1, rf_iter [50/60], loss_CE: 66.6513
#      RF training, Batch 1, rf_iter [60/60], loss_CE: 66.6490
#      RF training, Batch 15, rf_iter [1/60], loss_CE: 68.9020
#      RF training, Batch 15, rf_iter [10/60], loss_CE: 67.6994
#      RF training, Batch 15, rf_iter [20/60], loss_CE: 67.6179
#      RF training, Batch 15, rf_iter [30/60], loss_CE: 67.5996
#      RF training, Batch 15, rf_iter [40/60], loss_CE: 67.5930
#      RF training, Batch 15, rf_iter [50/60], loss_CE: 67.5899
#      RF training, Batch 15, rf_iter [60/60], loss_CE: 67.5883
#      RF training, Batch 30, rf_iter [1/60], loss_CE: 70.0647
#      RF training, Batch 30, rf_iter [10/60], loss_CE: 68.7932
#      RF training, Batch 30, rf_iter [20/60], loss_CE: 68.6961
#      RF training, Batch 30, rf_iter [30/60], loss_CE: 68.6725
#      RF training, Batch 30, rf_iter [40/60], loss_CE: 68.6636
#      RF training, Batch 30, rf_iter [50/60], loss_CE: 68.6593
#      RF training, Batch 30, rf_iter [60/60], loss_CE: 68.6570
#      RF training, Batch 45, rf_iter [1/60], loss_CE: 68.1046
#      RF training, Batch 45, rf_iter [10/60], loss_CE: 66.8184
#      RF training, Batch 45, rf_iter [20/60], loss_CE: 66.7517
#      RF training, Batch 45, rf_iter [30/60], loss_CE: 66.7352
#      RF training, Batch 45, rf_iter [40/60], loss_CE: 66.7285
#      RF training, Batch 45, rf_iter [50/60], loss_CE: 66.7251
#      RF training, Batch 45, rf_iter [60/60], loss_CE: 66.7231
#      RF training, Batch 60, rf_iter [1/60], loss_CE: 69.8834
#      RF training, Batch 60, rf_iter [10/60], loss_CE: 68.3367
#      RF training, Batch 60, rf_iter [20/60], loss_CE: 68.2520
#      RF training, Batch 60, rf_iter [30/60], loss_CE: 68.2333
#      RF training, Batch 60, rf_iter [40/60], loss_CE: 68.2265
#      RF training, Batch 60, rf_iter [50/60], loss_CE: 68.2233
#      RF training, Batch 60, rf_iter [60/60], loss_CE: 68.2215
#      RF training, Batch 75, rf_iter [1/60], loss_CE: 69.0018
#      RF training, Batch 75, rf_iter [10/60], loss_CE: 67.7652
#      RF training, Batch 75, rf_iter [20/60], loss_CE: 67.6861
#      RF training, Batch 75, rf_iter [30/60], loss_CE: 67.6658
#      RF training, Batch 75, rf_iter [40/60], loss_CE: 67.6571
#      RF training, Batch 75, rf_iter [50/60], loss_CE: 67.6522
#      RF training, Batch 75, rf_iter [60/60], loss_CE: 67.6490
#      RF training, coordinate loss: 56.70, after selcetion: 64.63
#      -----> RF training time: ## 106.25 mins ##
#      -----> Training time for this round: ## 258.04 mins ##
# ############################################################################
# Round [4/10], Using GPU
#      CNN training, Iter [1/200], loss_CE: 82.0904
#      CNN training, Iter [5/200], loss_CE: 81.9963
#      CNN training, Iter [10/200], loss_CE: 81.8945
#      CNN training, Iter [15/200], loss_CE: 81.8569
#      CNN training, Iter [20/200], loss_CE: 81.8319
#      CNN training, Iter [25/200], loss_CE: 81.8206
#      CNN training, Iter [30/200], loss_CE: 81.8190
#      CNN training, Iter [35/200], loss_CE: 81.8064
#      CNN training, Iter [40/200], loss_CE: 81.7988
#      CNN training, Iter [45/200], loss_CE: 81.7959
#      CNN training, Iter [50/200], loss_CE: 81.7824
#      CNN training, Iter [55/200], loss_CE: 81.7746
#      CNN training, Iter [60/200], loss_CE: 81.7746
#      CNN training, Iter [65/200], loss_CE: 81.7808
#      CNN training, Iter [70/200], loss_CE: 81.7704
#      CNN training, Iter [75/200], loss_CE: 81.7655
#      CNN training, Iter [80/200], loss_CE: 81.7667
#      CNN training, Iter [85/200], loss_CE: 81.7622
#      CNN training, Iter [90/200], loss_CE: 81.7585
#      CNN training, Iter [95/200], loss_CE: 81.7624
#      CNN training, Iter [100/200], loss_CE: 81.7575
#      CNN training, Iter [105/200], loss_CE: 81.7582
#      CNN training, Iter [110/200], loss_CE: 81.7540
#      CNN training, Iter [115/200], loss_CE: 81.7541
#      CNN training, Iter [120/200], loss_CE: 81.7461
#      CNN training, Iter [125/200], loss_CE: 81.7471
#      CNN training, Iter [130/200], loss_CE: 81.7514
#      CNN training, Iter [135/200], loss_CE: 81.7414
#      CNN training, Iter [140/200], loss_CE: 81.7414
#      CNN training, Iter [145/200], loss_CE: 81.7406
#      CNN training, Iter [150/200], loss_CE: 81.7469
#      CNN training, Iter [155/200], loss_CE: 81.7413
#      CNN training, Iter [160/200], loss_CE: 81.7327
#      CNN training, Iter [165/200], loss_CE: 81.7319
#      CNN training, Iter [170/200], loss_CE: 81.7346
#      CNN training, Iter [175/200], loss_CE: 81.7345
#      CNN training, Iter [180/200], loss_CE: 81.7357
#      CNN training, Iter [185/200], loss_CE: 81.7269
#      CNN training, Iter [190/200], loss_CE: 81.7188
#      CNN training, Iter [195/200], loss_CE: 81.7237
#      CNN training, Iter [200/200], loss_CE: 81.7204
#      -----> CNN training time: ## 163.07 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_CE: 67.7376
#      RF training, Batch 1, rf_iter [10/60], loss_CE: 66.6955
#      RF training, Batch 1, rf_iter [20/60], loss_CE: 66.6367
#      RF training, Batch 1, rf_iter [30/60], loss_CE: 66.6226
#      RF training, Batch 1, rf_iter [40/60], loss_CE: 66.6168
#      RF training, Batch 1, rf_iter [50/60], loss_CE: 66.6136
#      RF training, Batch 1, rf_iter [60/60], loss_CE: 66.6116
#      RF training, Batch 15, rf_iter [1/60], loss_CE: 68.7746
#      RF training, Batch 15, rf_iter [10/60], loss_CE: 67.5821
#      RF training, Batch 15, rf_iter [20/60], loss_CE: 67.5110
#      RF training, Batch 15, rf_iter [30/60], loss_CE: 67.4942
#      RF training, Batch 15, rf_iter [40/60], loss_CE: 67.4876
#      RF training, Batch 15, rf_iter [50/60], loss_CE: 67.4842
#      RF training, Batch 15, rf_iter [60/60], loss_CE: 67.4821
#      RF training, Batch 30, rf_iter [1/60], loss_CE: 69.1386
#      RF training, Batch 30, rf_iter [10/60], loss_CE: 67.8987
#      RF training, Batch 30, rf_iter [20/60], loss_CE: 67.8150
#      RF training, Batch 30, rf_iter [30/60], loss_CE: 67.7962
#      RF training, Batch 30, rf_iter [40/60], loss_CE: 67.7892
#      RF training, Batch 30, rf_iter [50/60], loss_CE: 67.7858
#      RF training, Batch 30, rf_iter [60/60], loss_CE: 67.7839
#      RF training, Batch 45, rf_iter [1/60], loss_CE: 68.0908
#      RF training, Batch 45, rf_iter [10/60], loss_CE: 67.1288
#      RF training, Batch 45, rf_iter [20/60], loss_CE: 67.0626
#      RF training, Batch 45, rf_iter [30/60], loss_CE: 67.0476
#      RF training, Batch 45, rf_iter [40/60], loss_CE: 67.0421
#      RF training, Batch 45, rf_iter [50/60], loss_CE: 67.0396
#      RF training, Batch 45, rf_iter [60/60], loss_CE: 67.0381
#      RF training, Batch 60, rf_iter [1/60], loss_CE: 69.5981
#      RF training, Batch 60, rf_iter [10/60], loss_CE: 68.1240
#      RF training, Batch 60, rf_iter [20/60], loss_CE: 68.0435
#      RF training, Batch 60, rf_iter [30/60], loss_CE: 68.0273
#      RF training, Batch 60, rf_iter [40/60], loss_CE: 68.0214
#      RF training, Batch 60, rf_iter [50/60], loss_CE: 68.0187
#      RF training, Batch 60, rf_iter [60/60], loss_CE: 68.0172
#      RF training, Batch 75, rf_iter [1/60], loss_CE: 68.8099
#      RF training, Batch 75, rf_iter [10/60], loss_CE: 67.7791
#      RF training, Batch 75, rf_iter [20/60], loss_CE: 67.7185
#      RF training, Batch 75, rf_iter [30/60], loss_CE: 67.7045
#      RF training, Batch 75, rf_iter [40/60], loss_CE: 67.6987
#      RF training, Batch 75, rf_iter [50/60], loss_CE: 67.6957
#      RF training, Batch 75, rf_iter [60/60], loss_CE: 67.6937
#      RF training, coordinate loss: 52.68, after selcetion: 62.44
#      -----> RF training time: ## 106.74 mins ##
#      -----> Training time for this round: ## 269.81 mins ##
# ############################################################################
# Round [5/10], Using GPU
#      CNN training, Iter [1/200], loss_CE: 81.1596
#      CNN training, Iter [5/200], loss_CE: 81.0891
#      CNN training, Iter [10/200], loss_CE: 81.0692
#      CNN training, Iter [15/200], loss_CE: 81.0586
#      CNN training, Iter [20/200], loss_CE: 81.0481
#      CNN training, Iter [25/200], loss_CE: 81.0380
#      CNN training, Iter [30/200], loss_CE: 81.0380
#      CNN training, Iter [35/200], loss_CE: 81.0305
#      CNN training, Iter [40/200], loss_CE: 81.0288
#      CNN training, Iter [45/200], loss_CE: 81.0183
#      CNN training, Iter [50/200], loss_CE: 81.0146
#      CNN training, Iter [55/200], loss_CE: 81.0101
#      CNN training, Iter [60/200], loss_CE: 81.0069
#      CNN training, Iter [65/200], loss_CE: 81.0094
#      CNN training, Iter [70/200], loss_CE: 81.0071
#      CNN training, Iter [75/200], loss_CE: 81.0025
#      CNN training, Iter [80/200], loss_CE: 81.0047
#      CNN training, Iter [85/200], loss_CE: 81.0019
#      CNN training, Iter [90/200], loss_CE: 80.9960
#      CNN training, Iter [95/200], loss_CE: 80.9927
#      CNN training, Iter [100/200], loss_CE: 80.9928
#      CNN training, Iter [105/200], loss_CE: 80.9929
#      CNN training, Iter [110/200], loss_CE: 80.9843
#      CNN training, Iter [115/200], loss_CE: 80.9809
#      CNN training, Iter [120/200], loss_CE: 80.9788
#      CNN training, Iter [125/200], loss_CE: 80.9861
#      CNN training, Iter [130/200], loss_CE: 80.9740
#      CNN training, Iter [135/200], loss_CE: 80.9724
#      CNN training, Iter [140/200], loss_CE: 80.9795
#      CNN training, Iter [145/200], loss_CE: 80.9712
#      CNN training, Iter [150/200], loss_CE: 80.9687
#      CNN training, Iter [155/200], loss_CE: 80.9705
#      CNN training, Iter [160/200], loss_CE: 80.9650
#      CNN training, Iter [165/200], loss_CE: 80.9647
#      CNN training, Iter [170/200], loss_CE: 80.9598
#      CNN training, Iter [175/200], loss_CE: 80.9703
#      CNN training, Iter [180/200], loss_CE: 80.9555
#      CNN training, Iter [185/200], loss_CE: 80.9527
#      CNN training, Iter [190/200], loss_CE: 80.9563
#      CNN training, Iter [195/200], loss_CE: 80.9539
#      CNN training, Iter [200/200], loss_CE: 80.9614
#      -----> CNN training time: ## 162.02 mins ##
#      RF training, Batch 1, rf_iter [1/60], loss_CE: 67.7474
#      RF training, Batch 1, rf_iter [10/60], loss_CE: 66.7989
#      RF training, Batch 1, rf_iter [20/60], loss_CE: 66.7335
#      RF training, Batch 1, rf_iter [30/60], loss_CE: 66.7160
#      RF training, Batch 1, rf_iter [40/60], loss_CE: 66.7092
#      RF training, Batch 1, rf_iter [50/60], loss_CE: 66.7059
#      RF training, Batch 1, rf_iter [60/60], loss_CE: 66.7040
#      RF training, Batch 15, rf_iter [1/60], loss_CE: 68.1090
#      RF training, Batch 15, rf_iter [10/60], loss_CE: 66.9750
#      RF training, Batch 15, rf_iter [20/60], loss_CE: 66.9160
#      RF training, Batch 15, rf_iter [30/60], loss_CE: 66.9016
#      RF training, Batch 15, rf_iter [40/60], loss_CE: 66.8960
#      RF training, Batch 15, rf_iter [50/60], loss_CE: 66.8930
#      RF training, Batch 15, rf_iter [60/60], loss_CE: 66.8912
#      RF training, Batch 30, rf_iter [1/60], loss_CE: 68.9218
#      RF training, Batch 30, rf_iter [10/60], loss_CE: 67.7541
#      RF training, Batch 30, rf_iter [20/60], loss_CE: 67.6816
#      RF training, Batch 30, rf_iter [30/60], loss_CE: 67.6652
#      RF training, Batch 30, rf_iter [40/60], loss_CE: 67.6590
#      RF training, Batch 30, rf_iter [50/60], loss_CE: 67.6561
#      RF training, Batch 30, rf_iter [60/60], loss_CE: 67.6544
#      RF training, Batch 45, rf_iter [1/60], loss_CE: 67.8107
#      RF training, Batch 45, rf_iter [10/60], loss_CE: 66.7549
#      RF training, Batch 45, rf_iter [20/60], loss_CE: 66.6850
#      RF training, Batch 45, rf_iter [30/60], loss_CE: 66.6667
#      RF training, Batch 45, rf_iter [40/60], loss_CE: 66.6593
#      RF training, Batch 45, rf_iter [50/60], loss_CE: 66.6555
#      RF training, Batch 45, rf_iter [60/60], loss_CE: 66.6534
#      RF training, Batch 60, rf_iter [1/60], loss_CE: 69.0799
#      RF training, Batch 60, rf_iter [10/60], loss_CE: 67.7406
#      RF training, Batch 60, rf_iter [20/60], loss_CE: 67.6697
#      RF training, Batch 60, rf_iter [30/60], loss_CE: 67.6550
#      RF training, Batch 60, rf_iter [40/60], loss_CE: 67.6497
#      RF training, Batch 60, rf_iter [50/60], loss_CE: 67.6472
#      RF training, Batch 60, rf_iter [60/60], loss_CE: 67.6458
#      RF training, Batch 75, rf_iter [1/60], loss_CE: 68.4570
#      RF training, Batch 75, rf_iter [10/60], loss_CE: 67.4202
#      RF training, Batch 75, rf_iter [20/60], loss_CE: 67.3622
#      RF training, Batch 75, rf_iter [30/60], loss_CE: 67.3474
#      RF training, Batch 75, rf_iter [40/60], loss_CE: 67.3412
#      RF training, Batch 75, rf_iter [50/60], loss_CE: 67.3380
#      RF training, Batch 75, rf_iter [60/60], loss_CE: 67.3360
#      RF training, coordinate loss: 51.88, after selcetion: 61.66
#      -----> RF training time: ## 107.03 mins ##
#      -----> Training time for this round: ## 269.05 mins ##
# ############################################################################
# Round [6/10], Using GPU
#      CNN training, Iter [1/200], loss_CE: 80.5967

# %%
for ith in range(20):
  px = pred_coord0[ith,::2].detach().cpu()
  py = pred_coord0[ith,1::2].detach().cpu()

  lx = coord[ith,36:48,0].detach().cpu()
  ly = coord[ith,36:48,1].detach().cpu()

  plt.scatter(lx,256-ly,label='Label')
  plt.scatter(px,256-py,label='Prediction')

  plt.xlim(0,256)
  plt.ylim(0,256)
  plt.title(str(ith)+"th Train Sample - Full")
  plt.legend(loc='lower left')
  plt.show()

# %%
for ith in range(20):
  px = pred_coord_select[ith,::2].detach().cpu()
  py = pred_coord-select[ith,1::2].detach().cpu()

  lx = coord[ith,36:48,0].detach().cpu()
  ly = coord[ith,36:48,1].detach().cpu()

  plt.scatter(lx,256-ly,label='Label')
  plt.scatter(px,256-py,label='Prediction')

  plt.xlim(0,256)
  plt.ylim(0,256)
  plt.title(str(ith)+"th Train Sample - Select")
  plt.legend(loc='lower left')
  plt.show()

# %% [markdown]
# ## 4.5 Test

# %% [markdown]
# ### Restore from saved weights

# %%
Tune_HGNet = HGNet(tune=True).to(device)
Tune_HGNet._HGNet__lin = nn.Sequential(nn.Conv2d(128,64,1),
                    nn.BatchNorm2d(64),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(4,4),  #(64,64,64)
                    nn.Conv2d(64,16,1),
                    nn.BatchNorm2d(16),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2),  #(16,32,32)
                    nn.Conv2d(16,4,1),
                    nn.BatchNorm2d(4),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2,2)).to(device)  #(4,16,16)

Tune_HGNet._HGNet__tune = nn.Sequential(nn.Linear(4*16*16,num_fc)).to(device)

Tune_HGNet.load_state_dict(torch.load(os.path.join("checkpoints/Anneal_Full_Train/Tune_HGNet_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_final.pt")))
leaf_q = torch.load(os.path.join("checkpoints/Anneal_Full_Train/leaf_q_var"+str(variance_gaussian)+"_LossKL_dim"+str(dim_tree)+"_num"+str(num_tree)+"_final.pt"))

# %%
import torchsummary
def count_parameters(model):
  return sum(p.numel() for p in model.parameters() if p.requires_grad)
torchsummary.summary(Tune_HGNet, (3,256,256))
print('parameters_count:',count_parameters(Tune_HGNet))

# %% [markdown]
# ### Test

# %%
def NME_eye(pred_coord, label_coord):
  # pred_coord(B,12*2)
  x = pred_coord[:,::2]
  y = pred_coord[:,1::2]
  x_label = label_coord[:,::2]
  y_label = label_coord[:,1::2]

  x_center_left = torch.sum(x[:,0:6],axis=1,keepdims=True)/6
  x_center_right = torch.sum(x[:,6:12],axis=1,keepdims=True)/6
  y_center_left = torch.sum(y[:,0:6],axis=1,keepdims=True)/6
  y_center_right = torch.sum(y[:,6:12],axis=1,keepdims=True)/6
  dist = torch.sqrt((x_center_left-x_center_right)**2 + (y_center_left-y_center_right)**2)

  Err = ((x-x_label)**2 + (y-y_label)**2)/dist
  return torch.sum(Err)/x.shape[0]/12

# %%
NME_loss_select = NME_loss = coord_loss = coord_loss_select = 0
Tune_HGNet.eval()

for i, (img,coord,hm) in enumerate(test_dataloder):
  img = img.float().to(device)
  img.requires_grad = True
  coord = coord.float().to(device)
  hm = hm.float().to(device)
  B = img.shape[0]
  
  outputs = Tune_HGNet.forward(img)
  pred_heatmaps = torch.matmul(phi(outputs),leaf_q.reshape(num_leaf_nodes,-1)) #(15,12*256*256)
  pred_heatmaps_select = torch.matmul(phi(outputs,mode='test'),leaf_q.reshape(num_leaf_nodes,-1)) #(15,12*256*256)
  pred_coord0 = find_coord(pred_heatmaps)
  pred_coords = find_coord(pred_heatmaps_select) #(15,12*2)

  #heatmap_loss += criterion(pred_heatmaps, hm[:,36:48,:,:].reshape(B,-1))
  coord_loss += torch.sum(torch.abs(pred_coord0-coord[:,36:48,:].reshape(B,-1)))/B
  coord_loss_select += torch.sum(torch.abs(pred_coords-coord[:,36:48,:].reshape(B,-1)))/B
  NME_loss += NME_eye(pred_coord0,coord[:,36:48,:].reshape(B,-1))
  NME_loss_select += NME_eye(pred_coords,coord[:,36:48,:].reshape(B,-1))

print("Coord L1 loss %.4f, after selection: %.4f" %(coord_loss/11, coord_loss_select/11))
print("Coord NME loss %.4f, after selection: %.4f" %(NME_loss/11, NME_loss_select/11))
# Out:
# Heatmap loss 0.00000005, Coord loss 71.2703, after selection: 67.2692

# %%
# Coords

for ith in range(10):
  x = pred_coord0[ith,::2].detach().cpu()
  y = pred_coord0[ith,1::2].detach().cpu()
  plt.scatter(x,256-y,label="Prediction")

  x2 = coord[ith,36:48,0].detach().cpu()
  y2 = coord[ith,36:48,1].detach().cpu()
  plt.scatter(x2,256-y2,label="GT")

  plt.legend(loc='lower left')
  plt.xlim(0,256)
  plt.ylim(0,256)
  plt.title(str(ith)+"th prediction - Full")
  plt.show()

# %%
# Coords

for ith in range(10):
  x = pred_coords[ith,::2].detach().cpu()
  y = pred_coords[ith,1::2].detach().cpu()
  plt.scatter(x,256-y,label="Prediction")

  x2 = coord[ith,36:48,0].detach().cpu()
  y2 = coord[ith,36:48,1].detach().cpu()
  plt.scatter(x2,256-y2,label="GT")

  plt.legend(loc='lower left')
  plt.xlim(0,256)
  plt.ylim(0,256)
  plt.title(str(ith)+"th prediction - Selected")
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a0c8a75a530f> in <module>()
#       2
#       3 for ith in range(10):
# ----> 4   x = pred_coords[ith,::2].detach().cpu()
#       5   y = pred_coords[ith,1::2].detach().cpu()
#       6   plt.scatter(x,256-y,label="Prediction")
#
# NameError: name 'pred_coords' is not defined

# %%
plot_heatmaps = pred_heatmaps.reshape(B,12,256,256).detach().cpu()
plot_heatmaps_all = torch.sum(plot_heatmaps,axis=1)
for ith in range(10):
  plt.imshow(plot_heatmaps_all[ith,:,:])
  plt.title(str(ith)+"th prediction heatmap")
  plt.show()

# %%
for nleaf in range(48):
  plt.imshow(leaf_q.reshape(num_leaf_nodes,12,256,256)[nleaf,0,:,:].detach().cpu())
  plt.title(str(ith)+"th leafnode, first point, first img")
  plt.show()

# %%
image = torch.sum(hm, axis=1).detach().cpu()
plt.imshow(image[ith,:,:])

# %%
plt.imshow(img[ith,:,:,:].detach().cpu().permute(1,2,0).int())
